# %%
# !pip install kaggle

# !mkdir .kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.13)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.26.15)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %%
import json
import zipfile
import os
from pathlib import Path
api_token = {"username":"ratchaphonp",
             "key":"9ce222230cae5d8fadeaa490ee7d9e29"}
kaggle_path = Path('/root/.kaggle')
os.makedirs(kaggle_path, exist_ok=True)

with open (kaggle_path/'kaggle.json', 'w') as handl:
    json.dump(api_token,handl)

# %%
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d ratchaphonp/new-image
# Out:
# Downloading new-image.zip to /content
# 100% 26.4G/26.4G [24:54<00:00, 22.5MB/s]
# 100% 26.4G/26.4G [24:54<00:00, 19.0MB/s]

# %%
# !unzip new-image.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/train/malignant/ca_train_1033.jpg
#   inflating: train/train/malignant/ca_train_1034.jpg
#   inflating: train/train/malignant/ca_train_1035.jpg
#   inflating: train/train/malignant/ca_train_1036.jpg
#   inflating: train/train/malignant/ca_train_1037.jpg
#   inflating: train/train/malignant/ca_train_1038.jpg
#   inflating: train/train/malignant/ca_train_1039.jpg
#   inflating: train/train/malignant/ca_train_104.jpg
#   inflating: train/train/malignant/ca_train_1040.jpg
#   inflating: train/train/malignant/ca_train_1041.jpg
#   inflating: train/train/malignant/ca_train_1042.jpg
#   inflating: train/train/malignant/ca_train_1043.jpg
#   inflating: train/train/malignant/ca_train_1044.jpg
#   inflating: train/train/malignant/ca_train_1045.jpg
#   inflating: train/train/malignant/ca_train_1046.jpg
#   inflating: train/train/malignant/ca_train_1047.jpg
#   inflating: train/train/malignant/ca_train_1048.jpg
#   inflating: train/train/malignant/ca_train_1049.jpg
#   inflating: train/train/malignant/ca_train_105.jpg
#   inflating: train/train/malignant/ca_train_1050.jpg
#   inflating: train/train/malignant/ca_train_1051.jpg
#   inflating: train/train/malignant/ca_train_1052.jpg
#   inflating: train/train/malignant/ca_train_1053.jpg
#   inflating: train/train/malignant/ca_train_1054.jpg
#   inflating: train/train/malignant/ca_train_1055.jpg
#   inflating: train/train/malignant/ca_train_1056.jpg
#   inflating: train/train/malignant/ca_train_1057.jpg
#   inflating: train/train/malignant/ca_train_1058.jpg
#   inflating: train/train/malignant/ca_train_1059.jpg
#   inflating: train/train/malignant/ca_train_106.jpg
#   inflating: train/train/malignant/ca_train_1060.jpg
#   inflating: train/train/malignant/ca_train_1061.jpg
#   inflating: train/train/malignant/ca_train_1062.jpg
#   inflating: train/train/malignant/ca_train_1063.jpg
#   inflating: train/train/malignant/ca_train_1064.jpg
#   inflating: train/train/malignant/ca_train_1065.jpg
#   inflating: train/train/malignant/ca_train_1066.jpg
#   inflating: train/train/malignant/ca_train_1067.jpg
#   inflating: train/train/malignant/ca_train_1068.jpg
#   inflating: train/train/malignant/ca_train_1069.jpg
#   inflating: train/train/malignant/ca_train_107.jpg
#   inflating: train/train/malignant/ca_train_1070.jpg
#   inflating: train/train/malignant/ca_train_1071.jpg
#   inflating: train/train/malignant/ca_train_1072.jpg
#   inflating: train/train/malignant/ca_train_1073.jpg
#   inflating: train/train/malignant/ca_train_1074.jpg
#   inflating: train/train/malignant/ca_train_1075.jpg
#   inflating: train/train/malignant/ca_train_1076.jpg
#   inflating: train/train/malignant/ca_train_1077.jpg
#   inflating: train/train/malignant/ca_train_1078.jpg
#   inflating: train/train/malignant/ca_train_1079.jpg
#   inflating: train/train/malignant/ca_train_108.jpg
#   inflating: train/train/malignant/ca_train_1080.jpg
#   inflating: train/train/malignant/ca_train_1081.jpg
#   inflating: train/train/malignant/ca_train_1082.jpg
#   inflating: train/train/malignant/ca_train_1083.jpg
#   inflating: train/train/malignant/ca_train_1084.jpg
#   inflating: train/train/malignant/ca_train_1085.jpg
#   inflating: train/train/malignant/ca_train_1086.jpg
#   inflating: train/train/malignant/ca_train_1087.jpg
#   inflating: train/train/malignant/ca_train_1088.jpg
#   inflating: train/train/malignant/ca_train_1089.jpg
#   inflating: train/train/malignant/ca_train_109.jpg
#   inflating: train/train/malignant/ca_train_1090.jpg
#   inflating: train/train/malignant/ca_train_1091.jpg
#   inflating: train/train/malignant/ca_train_1092.jpg
#   inflating: train/train/malignant/ca_train_1093.jpg
#   inflating: train/train/malignant/ca_train_1094.jpg
#   inflating: train/train/malignant/ca_train_1095.jpg
#   inflating: train/train/malignant/ca_train_1096.jpg
#   inflating: train/train/malignant/ca_train_1097.jpg
#   inflating: train/train/malignant/ca_train_1098.jpg
#   inflating: train/train/malignant/ca_train_1099.jpg
#   inflating: train/train/malignant/ca_train_11.jpg
#   inflating: train/train/malignant/ca_train_110.jpg
#   inflating: train/train/malignant/ca_train_1100.jpg
#   inflating: train/train/malignant/ca_train_1101.jpg
#   inflating: train/train/malignant/ca_train_1102.jpg
#   inflating: train/train/malignant/ca_train_1103.jpg
#   inflating: train/train/malignant/ca_train_1104.jpg
#   inflating: train/train/malignant/ca_train_1105.jpg
#   inflating: train/train/malignant/ca_train_1106.jpg
#   inflating: train/train/malignant/ca_train_1107.jpg
#   inflating: train/train/malignant/ca_train_1108.jpg
#   inflating: train/train/malignant/ca_train_1109.jpg
#   inflating: train/train/malignant/ca_train_111.jpg
#   inflating: train/train/malignant/ca_train_1110.jpg
#   inflating: train/train/malignant/ca_train_1111.jpg
#   inflating: train/train/malignant/ca_train_1112.jpg
#   inflating: train/train/malignant/ca_train_1113.jpg
#   inflating: train/train/malignant/ca_train_1114.jpg
#   inflating: train/train/malignant/ca_train_1115.jpg
#   inflating: train/train/malignant/ca_train_1116.jpg
#   inflating: train/train/malignant/ca_train_1117.jpg
#   inflating: train/train/malignant/ca_train_1118.jpg
#   inflating: train/train/malignant/ca_train_1119.jpg
#   inflating: train/train/malignant/ca_train_112.jpg
#   inflating: train/train/malignant/ca_train_1120.jpg
#   inflating: train/train/malignant/ca_train_1121.jpg
#   inflating: train/train/malignant/ca_train_1122.jpg
#   inflating: train/train/malignant/ca_train_1123.jpg
#   inflating: train/train/malignant/ca_train_1124.jpg
#   inflating: train/train/malignant/ca_train_1125.jpg
#   inflating: train/train/malignant/ca_train_1126.jpg
#   inflating: train/train/malignant/ca_train_1127.jpg
#   inflating: train/train/malignant/ca_train_1128.jpg
#   inflating: train/train/malignant/ca_train_1129.jpg
#   inflating: train/train/malignant/ca_train_113.jpg
#   inflating: train/train/malignant/ca_train_1130.jpg
#   inflating: train/train/malignant/ca_train_1131.jpg
#   inflating: train/train/malignant/ca_train_1132.jpg
#   inflating: train/train/malignant/ca_train_1133.jpg
#   inflating: train/train/malignant/ca_train_1134.jpg
#   inflating: train/train/malignant/ca_train_1135.jpg
#   inflating: train/train/malignant/ca_train_1136.jpg
#   inflating: train/train/malignant/ca_train_1137.jpg
#   inflating: train/train/malignant/ca_train_1138.jpg
#   inflating: train/train/malignant/ca_train_1139.jpg
#   inflating: train/train/malignant/ca_train_114.jpg
#   inflating: train/train/malignant/ca_train_1140.jpg
#   inflating: train/train/malignant/ca_train_1141.jpg
#   inflating: train/train/malignant/ca_train_1142.jpg
#   inflating: train/train/malignant/ca_train_1143.jpg
#   inflating: train/train/malignant/ca_train_1144.jpg
#   inflating: train/train/malignant/ca_train_1145.jpg
#   inflating: train/train/malignant/ca_train_1146.jpg
#   inflating: train/train/malignant/ca_train_1147.jpg
#   inflating: train/train/malignant/ca_train_1148.jpg
#   inflating: train/train/malignant/ca_train_1149.jpg
#   inflating: train/train/malignant/ca_train_115.jpg
#   inflating: train/train/malignant/ca_train_1150.jpg
#   inflating: train/train/malignant/ca_train_1151.jpg
#   inflating: train/train/malignant/ca_train_1152.jpg
#   inflating: train/train/malignant/ca_train_1153.jpg
#   inflating: train/train/malignant/ca_train_1154.jpg
#   inflating: train/train/malignant/ca_train_1155.jpg
#   inflating: train/train/malignant/ca_train_1156.jpg
#   inflating: train/train/malignant/ca_train_1157.jpg
#   inflating: train/train/malignant/ca_train_1158.jpg
#   inflating: train/train/malignant/ca_train_1159.jpg
#   inflating: train/train/malignant/ca_train_116.jpg
#   inflating: train/train/malignant/ca_train_1160.jpg
#   inflating: train/train/malignant/ca_train_1161.jpg
#   inflating: train/train/malignant/ca_train_1162.jpg
#   inflating: train/train/malignant/ca_train_1163.jpg
#   inflating: train/train/malignant/ca_train_1164.jpg
#   inflating: train/train/malignant/ca_train_1165.jpg
#   inflating: train/train/malignant/ca_train_1166.jpg
#   inflating: train/train/malignant/ca_train_1167.jpg
#   inflating: train/train/malignant/ca_train_1168.jpg
#   inflating: train/train/malignant/ca_train_1169.jpg
#   inflating: train/train/malignant/ca_train_117.jpg
#   inflating: train/train/malignant/ca_train_1170.jpg
#   inflating: train/train/malignant/ca_train_1171.jpg
#   inflating: train/train/malignant/ca_train_1172.jpg
#   inflating: train/train/malignant/ca_train_1173.jpg
#   inflating: train/train/malignant/ca_train_1174.jpg
#   inflating: train/train/malignant/ca_train_1175.jpg
#   inflating: train/train/malignant/ca_train_1176.jpg
#   inflating: train/train/malignant/ca_train_1177.jpg
#   inflating: train/train/malignant/ca_train_1178.jpg
#   inflating: train/train/malignant/ca_train_1179.jpg
#   inflating: train/train/malignant/ca_train_118.jpg
#   inflating: train/train/malignant/ca_train_1180.jpg
#   inflating: train/train/malignant/ca_train_1181.jpg
#   inflating: train/train/malignant/ca_train_1182.jpg
#   inflating: train/train/malignant/ca_train_1183.jpg
#   inflating: train/train/malignant/ca_train_1184.jpg
#   inflating: train/train/malignant/ca_train_1185.jpg
#   inflating: train/train/malignant/ca_train_1186.jpg
#   inflating: train/train/malignant/ca_train_1187.jpg
#   inflating: train/train/malignant/ca_train_1188.jpg
#   inflating: train/train/malignant/ca_train_1189.jpg
#   inflating: train/train/malignant/ca_train_119.jpg
#   inflating: train/train/malignant/ca_train_1190.jpg
#   inflating: train/train/malignant/ca_train_1191.jpg
#   inflating: train/train/malignant/ca_train_1192.jpg
#   inflating: train/train/malignant/ca_train_1193.jpg
#   inflating: train/train/malignant/ca_train_1194.jpg
#   inflating: train/train/malignant/ca_train_1195.jpg
#   inflating: train/train/malignant/ca_train_1196.jpg
#   inflating: train/train/malignant/ca_train_1197.jpg
#   inflating: train/train/malignant/ca_train_1198.jpg
#   inflating: train/train/malignant/ca_train_1199.jpg
#   inflating: train/train/malignant/ca_train_12.jpg
#   inflating: train/train/malignant/ca_train_120.jpg
#   inflating: train/train/malignant/ca_train_1200.jpg
#   inflating: train/train/malignant/ca_train_1201.jpg
#   inflating: train/train/malignant/ca_train_1202.jpg
#   inflating: train/train/malignant/ca_train_1203.jpg
#   inflating: train/train/malignant/ca_train_1204.jpg
#   inflating: train/train/malignant/ca_train_1205.jpg
#   inflating: train/train/malignant/ca_train_1206.jpg
#   inflating: train/train/malignant/ca_train_1207.jpg
#   inflating: train/train/malignant/ca_train_1208.jpg
#   inflating: train/train/malignant/ca_train_1209.jpg
#   inflating: train/train/malignant/ca_train_121.jpg
#   inflating: train/train/malignant/ca_train_1210.jpg
#   inflating: train/train/malignant/ca_train_1211.jpg
#   inflating: train/train/malignant/ca_train_1212.jpg
#   inflating: train/train/malignant/ca_train_1213.jpg
#   inflating: train/train/malignant/ca_train_1214.jpg
#   inflating: train/train/malignant/ca_train_1215.jpg
#   inflating: train/train/malignant/ca_train_1216.jpg
#   inflating: train/train/malignant/ca_train_1217.jpg
#   inflating: train/train/malignant/ca_train_1218.jpg
#   inflating: train/train/malignant/ca_train_1219.jpg
#   inflating: train/train/malignant/ca_train_122.jpg
#   inflating: train/train/malignant/ca_train_1220.jpg
#   inflating: train/train/malignant/ca_train_1221.jpg
#   inflating: train/train/malignant/ca_train_1222.jpg
#   inflating: train/train/malignant/ca_train_1223.jpg
#   inflating: train/train/malignant/ca_train_1224.jpg
#   inflating: train/train/malignant/ca_train_1225.jpg
#   inflating: train/train/malignant/ca_train_1226.jpg
#   inflating: train/train/malignant/ca_train_1227.jpg
#   inflating: train/train/malignant/ca_train_1228.jpg
#   inflating: train/train/malignant/ca_train_1229.jpg
#   inflating: train/train/malignant/ca_train_123.jpg
#   inflating: train/train/malignant/ca_train_1230.jpg
#   inflating: train/train/malignant/ca_train_1231.jpg
#   inflating: train/train/malignant/ca_train_1232.jpg
#   inflating: train/train/malignant/ca_train_1233.jpg
#   inflating: train/train/malignant/ca_train_1234.jpg
#   inflating: train/train/malignant/ca_train_1235.jpg
#   inflating: train/train/malignant/ca_train_1236.jpg
#   inflating: train/train/malignant/ca_train_1237.jpg
#   inflating: train/train/malignant/ca_train_1238.jpg
#   inflating: train/train/malignant/ca_train_1239.jpg
#   inflating: train/train/malignant/ca_train_124.jpg
#   inflating: train/train/malignant/ca_train_1240.jpg
#   inflating: train/train/malignant/ca_train_1241.jpg
#   inflating: train/train/malignant/ca_train_1242.jpg
#   inflating: train/train/malignant/ca_train_1243.jpg
#   inflating: train/train/malignant/ca_train_1244.jpg
#   inflating: train/train/malignant/ca_train_1245.jpg
#   inflating: train/train/malignant/ca_train_1246.jpg
#   inflating: train/train/malignant/ca_train_1247.jpg
#   inflating: train/train/malignant/ca_train_1248.jpg
#   inflating: train/train/malignant/ca_train_1249.jpg
#   inflating: train/train/malignant/ca_train_125.jpg
#   inflating: train/train/malignant/ca_train_1250.jpg
#   inflating: train/train/malignant/ca_train_1251.jpg
#   inflating: train/train/malignant/ca_train_1252.jpg
#   inflating: train/train/malignant/ca_train_1253.jpg
#   inflating: train/train/malignant/ca_train_1254.jpg
#   inflating: train/train/malignant/ca_train_1255.jpg
#   inflating: train/train/malignant/ca_train_1256.jpg
#   inflating: train/train/malignant/ca_train_1257.jpg
#   inflating: train/train/malignant/ca_train_1258.jpg
#   inflating: train/train/malignant/ca_train_1259.jpg
#   inflating: train/train/malignant/ca_train_126.jpg
#   inflating: train/train/malignant/ca_train_1260.jpg
#   inflating: train/train/malignant/ca_train_1261.jpg
#   inflating: train/train/malignant/ca_train_1262.jpg
#   inflating: train/train/malignant/ca_train_1263.jpg
#   inflating: train/train/malignant/ca_train_1264.jpg
#   inflating: train/train/malignant/ca_train_1265.jpg
#   inflating: train/train/malignant/ca_train_1266.jpg
#   inflating: train/train/malignant/ca_train_1267.jpg
#   inflating: train/train/malignant/ca_train_1268.jpg
#   inflating: train/train/malignant/ca_train_1269.jpg
#   inflating: train/train/malignant/ca_train_127.jpg
#   inflating: train/train/malignant/ca_train_1270.jpg
#   inflating: train/train/malignant/ca_train_1271.jpg
#   inflating: train/train/malignant/ca_train_1272.jpg
#   inflating: train/train/malignant/ca_train_1273.jpg
#   inflating: train/train/malignant/ca_train_1274.jpg
#   inflating: train/train/malignant/ca_train_1275.jpg
#   inflating: train/train/malignant/ca_train_1276.jpg
#   inflating: train/train/malignant/ca_train_1277.jpg
#   inflating: train/train/malignant/ca_train_1278.jpg
#   inflating: train/train/malignant/ca_train_1279.jpg
#   inflating: train/train/malignant/ca_train_128.jpg
#   inflating: train/train/malignant/ca_train_1280.jpg
#   inflating: train/train/malignant/ca_train_1281.jpg
#   inflating: train/train/malignant/ca_train_1282.jpg
#   inflating: train/train/malignant/ca_train_1283.jpg
#   inflating: train/train/malignant/ca_train_1284.jpg
#   inflating: train/train/malignant/ca_train_1285.jpg
#   inflating: train/train/malignant/ca_train_1286.jpg
#   inflating: train/train/malignant/ca_train_1287.jpg
#   inflating: train/train/malignant/ca_train_1288.jpg
#   inflating: train/train/malignant/ca_train_1289.jpg
#   inflating: train/train/malignant/ca_train_129.jpg
#   inflating: train/train/malignant/ca_train_1290.jpg
#   inflating: train/train/malignant/ca_train_1291.jpg
#   inflating: train/train/malignant/ca_train_1292.jpg
#   inflating: train/train/malignant/ca_train_1293.jpg
#   inflating: train/train/malignant/ca_train_1294.jpg
#   inflating: train/train/malignant/ca_train_1295.jpg
#   inflating: train/train/malignant/ca_train_1296.jpg
#   inflating: train/train/malignant/ca_train_1297.jpg
#   inflating: train/train/malignant/ca_train_1298.jpg
#   inflating: train/train/malignant/ca_train_1299.jpg
#   inflating: train/train/malignant/ca_train_13.jpg
#   inflating: train/train/malignant/ca_train_130.jpg
#   inflating: train/train/malignant/ca_train_1300.jpg
#   inflating: train/train/malignant/ca_train_1301.jpg
#   inflating: train/train/malignant/ca_train_1302.jpg
#   inflating: train/train/malignant/ca_train_1303.jpg
#   inflating: train/train/malignant/ca_train_1304.jpg
#   inflating: train/train/malignant/ca_train_1305.jpg
#   inflating: train/train/malignant/ca_train_1306.jpg
#   inflating: train/train/malignant/ca_train_1307.jpg
#   inflating: train/train/malignant/ca_train_1308.jpg
#   inflating: train/train/malignant/ca_train_1309.jpg
#   inflating: train/train/malignant/ca_train_131.jpg
#   inflating: train/train/malignant/ca_train_1310.jpg
#   inflating: train/train/malignant/ca_train_1311.jpg
#   inflating: train/train/malignant/ca_train_1312.jpg
#   inflating: train/train/malignant/ca_train_1313.jpg
#   inflating: train/train/malignant/ca_train_1314.jpg
#   inflating: train/train/malignant/ca_train_1315.jpg
#   inflating: train/train/malignant/ca_train_1316.jpg
#   inflating: train/train/malignant/ca_train_1317.jpg
#   inflating: train/train/malignant/ca_train_1318.jpg
#   inflating: train/train/malignant/ca_train_1319.jpg
#   inflating: train/train/malignant/ca_train_132.jpg
#   inflating: train/train/malignant/ca_train_1320.jpg
#   inflating: train/train/malignant/ca_train_1321.jpg
#   inflating: train/train/malignant/ca_train_1322.jpg
#   inflating: train/train/malignant/ca_train_1323.jpg
#   inflating: train/train/malignant/ca_train_1324.jpg
#   inflating: train/train/malignant/ca_train_1325.jpg
#   inflating: train/train/malignant/ca_train_1326.jpg
#   inflating: train/train/malignant/ca_train_1327.jpg
#   inflating: train/train/malignant/ca_train_1328.jpg
#   inflating: train/train/malignant/ca_train_1329.jpg
#   inflating: train/train/malignant/ca_train_133.jpg
#   inflating: train/train/malignant/ca_train_1330.jpg
#   inflating: train/train/malignant/ca_train_1331.jpg
#   inflating: train/train/malignant/ca_train_1332.jpg
#   inflating: train/train/malignant/ca_train_1333.jpg
#   inflating: train/train/malignant/ca_train_1334.jpg
#   inflating: train/train/malignant/ca_train_1335.jpg
#   inflating: train/train/malignant/ca_train_1336.jpg
#   inflating: train/train/malignant/ca_train_1337.jpg
#   inflating: train/train/malignant/ca_train_1338.jpg
#   inflating: train/train/malignant/ca_train_1339.jpg
#   inflating: train/train/malignant/ca_train_134.jpg
#   inflating: train/train/malignant/ca_train_1340.jpg
#   inflating: train/train/malignant/ca_train_1341.jpg
#   inflating: train/train/malignant/ca_train_1342.jpg
#   inflating: train/train/malignant/ca_train_1343.jpg
#   inflating: train/train/malignant/ca_train_1344.jpg
#   inflating: train/train/malignant/ca_train_1345.jpg
#   inflating: train/train/malignant/ca_train_1346.jpg
#   inflating: train/train/malignant/ca_train_1347.jpg
#   inflating: train/train/malignant/ca_train_1348.jpg
#   inflating: train/train/malignant/ca_train_1349.jpg
#   inflating: train/train/malignant/ca_train_135.jpg
#   inflating: train/train/malignant/ca_train_1350.jpg
#   inflating: train/train/malignant/ca_train_1351.jpg
#   inflating: train/train/malignant/ca_train_1352.jpg
#   inflating: train/train/malignant/ca_train_1353.jpg
#   inflating: train/train/malignant/ca_train_1354.jpg
#   inflating: train/train/malignant/ca_train_1355.jpg
#   inflating: train/train/malignant/ca_train_1356.jpg
#   inflating: train/train/malignant/ca_train_1357.jpg
#   inflating: train/train/malignant/ca_train_1358.jpg
#   inflating: train/train/malignant/ca_train_1359.jpg
#   inflating: train/train/malignant/ca_train_136.jpg
#   inflating: train/train/malignant/ca_train_1360.jpg
#   inflating: train/train/malignant/ca_train_1361.jpg
#   inflating: train/train/malignant/ca_train_1362.jpg
#   inflating: train/train/malignant/ca_train_1363.jpg
#   inflating: train/train/malignant/ca_train_1364.jpg
#   inflating: train/train/malignant/ca_train_1365.jpg
#   inflating: train/train/malignant/ca_train_1366.jpg
#   inflating: train/train/malignant/ca_train_1367.jpg
#   inflating: train/train/malignant/ca_train_1368.jpg
#   inflating: train/train/malignant/ca_train_1369.jpg
#   inflating: train/train/malignant/ca_train_137.jpg
#   inflating: train/train/malignant/ca_train_1370.jpg
#   inflating: train/train/malignant/ca_train_1371.jpg
#   inflating: train/train/malignant/ca_train_1372.jpg
#   inflating: train/train/malignant/ca_train_1373.jpg
#   inflating: train/train/malignant/ca_train_1374.jpg
#   inflating: train/train/malignant/ca_train_1375.jpg
#   inflating: train/train/malignant/ca_train_1376.jpg
#   inflating: train/train/malignant/ca_train_1377.jpg
#   inflating: train/train/malignant/ca_train_1378.jpg
#   inflating: train/train/malignant/ca_train_1379.jpg
#   inflating: train/train/malignant/ca_train_138.jpg
#   inflating: train/train/malignant/ca_train_1380.jpg
#   inflating: train/train/malignant/ca_train_1381.jpg
#   inflating: train/train/malignant/ca_train_1382.jpg
#   inflating: train/train/malignant/ca_train_1383.jpg
#   inflating: train/train/malignant/ca_train_1384.jpg
#   inflating: train/train/malignant/ca_train_1385.jpg
#   inflating: train/train/malignant/ca_train_1386.jpg
#   inflating: train/train/malignant/ca_train_1387.jpg
#   inflating: train/train/malignant/ca_train_1388.jpg
#   inflating: train/train/malignant/ca_train_1389.jpg
#   inflating: train/train/malignant/ca_train_139.jpg
#   inflating: train/train/malignant/ca_train_1390.jpg
#   inflating: train/train/malignant/ca_train_1391.jpg
#   inflating: train/train/malignant/ca_train_1392.jpg
#   inflating: train/train/malignant/ca_train_1393.jpg
#   inflating: train/train/malignant/ca_train_1394.jpg
#   inflating: train/train/malignant/ca_train_1395.jpg
#   inflating: train/train/malignant/ca_train_1396.jpg
#   inflating: train/train/malignant/ca_train_1397.jpg
#   inflating: train/train/malignant/ca_train_1398.jpg
#   inflating: train/train/malignant/ca_train_1399.jpg
#   inflating: train/train/malignant/ca_train_14.jpg
#   inflating: train/train/malignant/ca_train_140.jpg
#   inflating: train/train/malignant/ca_train_1400.jpg
#   inflating: train/train/malignant/ca_train_1401.jpg
#   inflating: train/train/malignant/ca_train_1402.jpg
#   inflating: train/train/malignant/ca_train_1403.jpg
#   inflating: train/train/malignant/ca_train_1404.jpg
#   inflating: train/train/malignant/ca_train_1405.jpg
#   inflating: train/train/malignant/ca_train_1406.jpg
#   inflating: train/train/malignant/ca_train_1407.jpg
#   inflating: train/train/malignant/ca_train_1408.jpg
#   inflating: train/train/malignant/ca_train_1409.jpg
#   inflating: train/train/malignant/ca_train_141.jpg
#   inflating: train/train/malignant/ca_train_1410.jpg
#   inflating: train/train/malignant/ca_train_1411.jpg
#   inflating: train/train/malignant/ca_train_1412.jpg
#   inflating: train/train/malignant/ca_train_1413.jpg
#   inflating: train/train/malignant/ca_train_1414.jpg
#   inflating: train/train/malignant/ca_train_1415.jpg
#   inflating: train/train/malignant/ca_train_1416.jpg
#   inflating: train/train/malignant/ca_train_1417.jpg
#   inflating: train/train/malignant/ca_train_1418.jpg
#   inflating: train/train/malignant/ca_train_1419.jpg
#   inflating: train/train/malignant/ca_train_142.jpg
#   inflating: train/train/malignant/ca_train_1420.jpg
#   inflating: train/train/malignant/ca_train_1421.jpg
#   inflating: train/train/malignant/ca_train_1422.jpg
#   inflating: train/train/malignant/ca_train_1423.jpg
#   inflating: train/train/malignant/ca_train_1424.jpg
#   inflating: train/train/malignant/ca_train_1425.jpg
#   inflating: train/train/malignant/ca_train_1426.jpg
#   inflating: train/train/malignant/ca_train_1427.jpg
#   inflating: train/train/malignant/ca_train_1428.jpg
#   inflating: train/train/malignant/ca_train_1429.jpg
#   inflating: train/train/malignant/ca_train_143.jpg
#   inflating: train/train/malignant/ca_train_1430.jpg
#   inflating: train/train/malignant/ca_train_1431.jpg
#   inflating: train/train/malignant/ca_train_1432.jpg
#   inflating: train/train/malignant/ca_train_1433.jpg
#   inflating: train/train/malignant/ca_train_1434.jpg
#   inflating: train/train/malignant/ca_train_1435.jpg
#   inflating: train/train/malignant/ca_train_1436.jpg
#   inflating: train/train/malignant/ca_train_1437.jpg
#   inflating: train/train/malignant/ca_train_1438.jpg
#   inflating: train/train/malignant/ca_train_1439.jpg
#   inflating: train/train/malignant/ca_train_144.jpg
#   inflating: train/train/malignant/ca_train_1440.jpg
#   inflating: train/train/malignant/ca_train_1441.jpg
#   inflating: train/train/malignant/ca_train_1442.jpg
#   inflating: train/train/malignant/ca_train_1443.jpg
#   inflating: train/train/malignant/ca_train_1444.jpg
#   inflating: train/train/malignant/ca_train_1445.jpg
#   inflating: train/train/malignant/ca_train_1446.jpg
#   inflating: train/train/malignant/ca_train_1447.jpg
#   inflating: train/train/malignant/ca_train_1448.jpg
#   inflating: train/train/malignant/ca_train_1449.jpg
#   inflating: train/train/malignant/ca_train_145.jpg
#   inflating: train/train/malignant/ca_train_1450.jpg
#   inflating: train/train/malignant/ca_train_1451.jpg
#   inflating: train/train/malignant/ca_train_1452.jpg
#   inflating: train/train/malignant/ca_train_1453.jpg
#   inflating: train/train/malignant/ca_train_1454.jpg
#   inflating: train/train/malignant/ca_train_1455.jpg
#   inflating: train/train/malignant/ca_train_1456.jpg
#   inflating: train/train/malignant/ca_train_1457.jpg
#   inflating: train/train/malignant/ca_train_1458.jpg
#   inflating: train/train/malignant/ca_train_1459.jpg
#   inflating: train/train/malignant/ca_train_146.jpg
#   inflating: train/train/malignant/ca_train_1460.jpg
#   inflating: train/train/malignant/ca_train_1461.jpg
#   inflating: train/train/malignant/ca_train_1462.jpg
#   inflating: train/train/malignant/ca_train_1463.jpg
#   inflating: train/train/malignant/ca_train_1464.jpg
#   inflating: train/train/malignant/ca_train_1465.jpg
#   inflating: train/train/malignant/ca_train_1466.jpg
#   inflating: train/train/malignant/ca_train_1467.jpg
#   inflating: train/train/malignant/ca_train_1468.jpg
#   inflating: train/train/malignant/ca_train_1469.jpg
#   inflating: train/train/malignant/ca_train_147.jpg
#   inflating: train/train/malignant/ca_train_1470.jpg
#   inflating: train/train/malignant/ca_train_1471.jpg
#   inflating: train/train/malignant/ca_train_1472.jpg
#   inflating: train/train/malignant/ca_train_1473.jpg
#   inflating: train/train/malignant/ca_train_1474.jpg
#   inflating: train/train/malignant/ca_train_1475.jpg
#   inflating: train/train/malignant/ca_train_1476.jpg
#   inflating: train/train/malignant/ca_train_1477.jpg
#   inflating: train/train/malignant/ca_train_1478.jpg
#   inflating: train/train/malignant/ca_train_1479.jpg
#   inflating: train/train/malignant/ca_train_148.jpg
#   inflating: train/train/malignant/ca_train_1480.jpg
#   inflating: train/train/malignant/ca_train_1481.jpg
#   inflating: train/train/malignant/ca_train_1482.jpg
#   inflating: train/train/malignant/ca_train_1483.jpg
#   inflating: train/train/malignant/ca_train_1484.jpg
#   inflating: train/train/malignant/ca_train_1485.jpg
#   inflating: train/train/malignant/ca_train_1486.jpg
#   inflating: train/train/malignant/ca_train_1487.jpg
#   inflating: train/train/malignant/ca_train_1488.jpg
#   inflating: train/train/malignant/ca_train_1489.jpg
#   inflating: train/train/malignant/ca_train_149.jpg
#   inflating: train/train/malignant/ca_train_1490.jpg
#   inflating: train/train/malignant/ca_train_1491.jpg
#   inflating: train/train/malignant/ca_train_1492.jpg
#   inflating: train/train/malignant/ca_train_1493.jpg
#   inflating: train/train/malignant/ca_train_1494.jpg
#   inflating: train/train/malignant/ca_train_1495.jpg
#   inflating: train/train/malignant/ca_train_1496.jpg
#   inflating: train/train/malignant/ca_train_1497.jpg
#   inflating: train/train/malignant/ca_train_1498.jpg
#   inflating: train/train/malignant/ca_train_1499.jpg
#   inflating: train/train/malignant/ca_train_15.jpg
#   inflating: train/train/malignant/ca_train_150.jpg
#   inflating: train/train/malignant/ca_train_1500.jpg
#   inflating: train/train/malignant/ca_train_1501.jpg
#   inflating: train/train/malignant/ca_train_1502.jpg
#   inflating: train/train/malignant/ca_train_1503.jpg
#   inflating: train/train/malignant/ca_train_1504.jpg
#   inflating: train/train/malignant/ca_train_1505.jpg
#   inflating: train/train/malignant/ca_train_1506.jpg
#   inflating: train/train/malignant/ca_train_1507.jpg
#   inflating: train/train/malignant/ca_train_1508.jpg
#   inflating: train/train/malignant/ca_train_1509.jpg
#   inflating: train/train/malignant/ca_train_151.jpg
#   inflating: train/train/malignant/ca_train_1510.jpg
#   inflating: train/train/malignant/ca_train_1511.jpg
#   inflating: train/train/malignant/ca_train_1512.jpg
#   inflating: train/train/malignant/ca_train_1513.jpg
#   inflating: train/train/malignant/ca_train_1514.jpg
#   inflating: train/train/malignant/ca_train_1515.jpg
#   inflating: train/train/malignant/ca_train_1516.jpg
#   inflating: train/train/malignant/ca_train_1517.jpg
#   inflating: train/train/malignant/ca_train_1518.jpg
#   inflating: train/train/malignant/ca_train_1519.jpg
#   inflating: train/train/malignant/ca_train_152.jpg
#   inflating: train/train/malignant/ca_train_1520.jpg
#   inflating: train/train/malignant/ca_train_1521.jpg
#   inflating: train/train/malignant/ca_train_1522.jpg
#   inflating: train/train/malignant/ca_train_1523.jpg
#   inflating: train/train/malignant/ca_train_1524.jpg
#   inflating: train/train/malignant/ca_train_1525.jpg
#   inflating: train/train/malignant/ca_train_1526.jpg
#   inflating: train/train/malignant/ca_train_1527.jpg
#   inflating: train/train/malignant/ca_train_1528.jpg
#   inflating: train/train/malignant/ca_train_1529.jpg
#   inflating: train/train/malignant/ca_train_153.jpg
#   inflating: train/train/malignant/ca_train_1530.jpg
#   inflating: train/train/malignant/ca_train_1531.jpg
#   inflating: train/train/malignant/ca_train_1532.jpg
#   inflating: train/train/malignant/ca_train_1533.jpg
#   inflating: train/train/malignant/ca_train_1534.jpg
#   inflating: train/train/malignant/ca_train_1535.jpg
#   inflating: train/train/malignant/ca_train_1536.jpg
#   inflating: train/train/malignant/ca_train_1537.jpg
#   inflating: train/train/malignant/ca_train_1538.jpg
#   inflating: train/train/malignant/ca_train_1539.jpg
#   inflating: train/train/malignant/ca_train_154.jpg
#   inflating: train/train/malignant/ca_train_1540.jpg
#   inflating: train/train/malignant/ca_train_1541.jpg
#   inflating: train/train/malignant/ca_train_1542.jpg
#   inflating: train/train/malignant/ca_train_1543.jpg
#   inflating: train/train/malignant/ca_train_1544.jpg
#   inflating: train/train/malignant/ca_train_1545.jpg
#   inflating: train/train/malignant/ca_train_1546.jpg
#   inflating: train/train/malignant/ca_train_1547.jpg
#   inflating: train/train/malignant/ca_train_1548.jpg
#   inflating: train/train/malignant/ca_train_1549.jpg
#   inflating: train/train/malignant/ca_train_155.jpg
#   inflating: train/train/malignant/ca_train_1550.jpg
#   inflating: train/train/malignant/ca_train_1551.jpg
#   inflating: train/train/malignant/ca_train_1552.jpg
#   inflating: train/train/malignant/ca_train_1553.jpg
#   inflating: train/train/malignant/ca_train_1554.jpg
#   inflating: train/train/malignant/ca_train_1555.jpg
#   inflating: train/train/malignant/ca_train_1556.jpg
#   inflating: train/train/malignant/ca_train_1557.jpg
#   inflating: train/train/malignant/ca_train_1558.jpg
#   inflating: train/train/malignant/ca_train_1559.jpg
#   inflating: train/train/malignant/ca_train_156.jpg
#   inflating: train/train/malignant/ca_train_1560.jpg
#   inflating: train/train/malignant/ca_train_1561.jpg
#   inflating: train/train/malignant/ca_train_1562.jpg
#   inflating: train/train/malignant/ca_train_1563.jpg
#   inflating: train/train/malignant/ca_train_1564.jpg
#   inflating: train/train/malignant/ca_train_1565.jpg
#   inflating: train/train/malignant/ca_train_1566.jpg
#   inflating: train/train/malignant/ca_train_1567.jpg
#   inflating: train/train/malignant/ca_train_1568.jpg
#   inflating: train/train/malignant/ca_train_1569.jpg
#   inflating: train/train/malignant/ca_train_157.jpg
#   inflating: train/train/malignant/ca_train_1570.jpg
#   inflating: train/train/malignant/ca_train_1571.jpg
#   inflating: train/train/malignant/ca_train_1572.jpg
#   inflating: train/train/malignant/ca_train_1573.jpg
#   inflating: train/train/malignant/ca_train_1574.jpg
#   inflating: train/train/malignant/ca_train_1575.jpg
#   inflating: train/train/malignant/ca_train_1576.jpg
#   inflating: train/train/malignant/ca_train_1577.jpg
#   inflating: train/train/malignant/ca_train_1578.jpg
#   inflating: train/train/malignant/ca_train_1579.jpg
#   inflating: train/train/malignant/ca_train_158.jpg
#   inflating: train/train/malignant/ca_train_1580.jpg
#   inflating: train/train/malignant/ca_train_1581.jpg
#   inflating: train/train/malignant/ca_train_1582.jpg
#   inflating: train/train/malignant/ca_train_1583.jpg
#   inflating: train/train/malignant/ca_train_1584.jpg
#   inflating: train/train/malignant/ca_train_1585.jpg
#   inflating: train/train/malignant/ca_train_1586.jpg
#   inflating: train/train/malignant/ca_train_1587.jpg
#   inflating: train/train/malignant/ca_train_1588.jpg
#   inflating: train/train/malignant/ca_train_1589.jpg
#   inflating: train/train/malignant/ca_train_159.jpg
#   inflating: train/train/malignant/ca_train_1590.jpg
#   inflating: train/train/malignant/ca_train_1591.jpg
#   inflating: train/train/malignant/ca_train_1592.jpg
#   inflating: train/train/malignant/ca_train_1593.jpg
#   inflating: train/train/malignant/ca_train_1594.jpg
#   inflating: train/train/malignant/ca_train_1595.jpg
#   inflating: train/train/malignant/ca_train_1596.jpg
#   inflating: train/train/malignant/ca_train_1597.jpg
#   inflating: train/train/malignant/ca_train_1598.jpg
#   inflating: train/train/malignant/ca_train_1599.jpg
#   inflating: train/train/malignant/ca_train_16.jpg
#   inflating: train/train/malignant/ca_train_160.jpg
#   inflating: train/train/malignant/ca_train_1600.jpg
#   inflating: train/train/malignant/ca_train_1601.jpg
#   inflating: train/train/malignant/ca_train_1602.jpg
#   inflating: train/train/malignant/ca_train_1603.jpg
#   inflating: train/train/malignant/ca_train_1604.jpg
#   inflating: train/train/malignant/ca_train_1605.jpg
#   inflating: train/train/malignant/ca_train_1606.jpg
#   inflating: train/train/malignant/ca_train_1607.jpg
#   inflating: train/train/malignant/ca_train_1608.jpg
#   inflating: train/train/malignant/ca_train_1609.jpg
#   inflating: train/train/malignant/ca_train_161.jpg
#   inflating: train/train/malignant/ca_train_1610.jpg
#   inflating: train/train/malignant/ca_train_1611.jpg
#   inflating: train/train/malignant/ca_train_1612.jpg
#   inflating: train/train/malignant/ca_train_1613.jpg
#   inflating: train/train/malignant/ca_train_1614.jpg
#   inflating: train/train/malignant/ca_train_1615.jpg
#   inflating: train/train/malignant/ca_train_1616.jpg
#   inflating: train/train/malignant/ca_train_1617.jpg
#   inflating: train/train/malignant/ca_train_1618.jpg
#   inflating: train/train/malignant/ca_train_1619.jpg
#   inflating: train/train/malignant/ca_train_162.jpg
#   inflating: train/train/malignant/ca_train_1620.jpg
#   inflating: train/train/malignant/ca_train_1621.jpg
#   inflating: train/train/malignant/ca_train_1622.jpg
#   inflating: train/train/malignant/ca_train_1623.jpg
#   inflating: train/train/malignant/ca_train_1624.jpg
#   inflating: train/train/malignant/ca_train_1625.jpg
#   inflating: train/train/malignant/ca_train_1626.jpg
#   inflating: train/train/malignant/ca_train_1627.jpg
#   inflating: train/train/malignant/ca_train_1628.jpg
#   inflating: train/train/malignant/ca_train_1629.jpg
#   inflating: train/train/malignant/ca_train_163.jpg
#   inflating: train/train/malignant/ca_train_1630.jpg
#   inflating: train/train/malignant/ca_train_1631.jpg
#   inflating: train/train/malignant/ca_train_1632.jpg
#   inflating: train/train/malignant/ca_train_1633.jpg
#   inflating: train/train/malignant/ca_train_1634.jpg
#   inflating: train/train/malignant/ca_train_1635.jpg
#   inflating: train/train/malignant/ca_train_1636.jpg
#   inflating: train/train/malignant/ca_train_1637.jpg
#   inflating: train/train/malignant/ca_train_1638.jpg
#   inflating: train/train/malignant/ca_train_1639.jpg
#   inflating: train/train/malignant/ca_train_164.jpg
#   inflating: train/train/malignant/ca_train_1640.jpg
#   inflating: train/train/malignant/ca_train_1641.jpg
#   inflating: train/train/malignant/ca_train_1642.jpg
#   inflating: train/train/malignant/ca_train_1643.jpg
#   inflating: train/train/malignant/ca_train_1644.jpg
#   inflating: train/train/malignant/ca_train_1645.jpg
#   inflating: train/train/malignant/ca_train_1646.jpg
#   inflating: train/train/malignant/ca_train_1647.jpg
#   inflating: train/train/malignant/ca_train_1648.jpg
#   inflating: train/train/malignant/ca_train_1649.jpg
#   inflating: train/train/malignant/ca_train_165.jpg
#   inflating: train/train/malignant/ca_train_1650.jpg
#   inflating: train/train/malignant/ca_train_1651.jpg
#   inflating: train/train/malignant/ca_train_1652.jpg
#   inflating: train/train/malignant/ca_train_1653.jpg
#   inflating: train/train/malignant/ca_train_1654.jpg
#   inflating: train/train/malignant/ca_train_1655.jpg
#   inflating: train/train/malignant/ca_train_1656.jpg
#   inflating: train/train/malignant/ca_train_1657.jpg
#   inflating: train/train/malignant/ca_train_1658.jpg
#   inflating: train/train/malignant/ca_train_1659.jpg
#   inflating: train/train/malignant/ca_train_166.jpg
#   inflating: train/train/malignant/ca_train_1660.jpg
#   inflating: train/train/malignant/ca_train_1661.jpg
#   inflating: train/train/malignant/ca_train_1662.jpg
#   inflating: train/train/malignant/ca_train_1663.jpg
#   inflating: train/train/malignant/ca_train_1664.jpg
#   inflating: train/train/malignant/ca_train_1665.jpg
#   inflating: train/train/malignant/ca_train_1666.jpg
#   inflating: train/train/malignant/ca_train_1667.jpg
#   inflating: train/train/malignant/ca_train_1668.jpg
#   inflating: train/train/malignant/ca_train_1669.jpg
#   inflating: train/train/malignant/ca_train_167.jpg
#   inflating: train/train/malignant/ca_train_1670.jpg
#   inflating: train/train/malignant/ca_train_1671.jpg
#   inflating: train/train/malignant/ca_train_1672.jpg
#   inflating: train/train/malignant/ca_train_1673.jpg
#   inflating: train/train/malignant/ca_train_1674.jpg
#   inflating: train/train/malignant/ca_train_1675.jpg
#   inflating: train/train/malignant/ca_train_1676.jpg
#   inflating: train/train/malignant/ca_train_1677.jpg
#   inflating: train/train/malignant/ca_train_1678.jpg
#   inflating: train/train/malignant/ca_train_1679.jpg
#   inflating: train/train/malignant/ca_train_168.jpg
#   inflating: train/train/malignant/ca_train_1680.jpg
#   inflating: train/train/malignant/ca_train_1681.jpg
#   inflating: train/train/malignant/ca_train_1682.jpg
#   inflating: train/train/malignant/ca_train_1683.jpg
#   inflating: train/train/malignant/ca_train_1684.jpg
#   inflating: train/train/malignant/ca_train_1685.jpg
#   inflating: train/train/malignant/ca_train_1686.jpg
#   inflating: train/train/malignant/ca_train_1687.jpg
#   inflating: train/train/malignant/ca_train_1688.jpg
#   inflating: train/train/malignant/ca_train_1689.jpg
#   inflating: train/train/malignant/ca_train_169.jpg
#   inflating: train/train/malignant/ca_train_1690.jpg
#   inflating: train/train/malignant/ca_train_1691.jpg
#   inflating: train/train/malignant/ca_train_1692.jpg
#   inflating: train/train/malignant/ca_train_1693.jpg
#   inflating: train/train/malignant/ca_train_1694.jpg
#   inflating: train/train/malignant/ca_train_1695.jpg
#   inflating: train/train/malignant/ca_train_1696.jpg
#   inflating: train/train/malignant/ca_train_1697.jpg
#   inflating: train/train/malignant/ca_train_1698.jpg
#   inflating: train/train/malignant/ca_train_1699.jpg
#   inflating: train/train/malignant/ca_train_17.jpg
#   inflating: train/train/malignant/ca_train_170.jpg
#   inflating: train/train/malignant/ca_train_1700.jpg
#   inflating: train/train/malignant/ca_train_1701.jpg
#   inflating: train/train/malignant/ca_train_1702.jpg
#   inflating: train/train/malignant/ca_train_1703.jpg
#   inflating: train/train/malignant/ca_train_1704.jpg
#   inflating: train/train/malignant/ca_train_1705.jpg
#   inflating: train/train/malignant/ca_train_1706.jpg
#   inflating: train/train/malignant/ca_train_1707.jpg
#   inflating: train/train/malignant/ca_train_1708.jpg
#   inflating: train/train/malignant/ca_train_1709.jpg
#   inflating: train/train/malignant/ca_train_171.jpg
#   inflating: train/train/malignant/ca_train_1710.jpg
#   inflating: train/train/malignant/ca_train_1711.jpg
#   inflating: train/train/malignant/ca_train_1712.jpg
#   inflating: train/train/malignant/ca_train_1713.jpg
#   inflating: train/train/malignant/ca_train_1714.jpg
#   inflating: train/train/malignant/ca_train_1715.jpg
#   inflating: train/train/malignant/ca_train_1716.jpg
#   inflating: train/train/malignant/ca_train_1717.jpg
#   inflating: train/train/malignant/ca_train_1718.jpg
#   inflating: train/train/malignant/ca_train_1719.jpg
#   inflating: train/train/malignant/ca_train_172.jpg
#   inflating: train/train/malignant/ca_train_1720.jpg
#   inflating: train/train/malignant/ca_train_1721.jpg
#   inflating: train/train/malignant/ca_train_1722.jpg
#   inflating: train/train/malignant/ca_train_1723.jpg
#   inflating: train/train/malignant/ca_train_1724.jpg
#   inflating: train/train/malignant/ca_train_1725.jpg
#   inflating: train/train/malignant/ca_train_1726.jpg
#   inflating: train/train/malignant/ca_train_1727.jpg
#   inflating: train/train/malignant/ca_train_1728.jpg
#   inflating: train/train/malignant/ca_train_1729.jpg
#   inflating: train/train/malignant/ca_train_173.jpg
#   inflating: train/train/malignant/ca_train_1730.jpg
#   inflating: train/train/malignant/ca_train_1731.jpg
#   inflating: train/train/malignant/ca_train_1732.jpg
#   inflating: train/train/malignant/ca_train_1733.jpg
#   inflating: train/train/malignant/ca_train_1734.jpg
#   inflating: train/train/malignant/ca_train_1735.jpg
#   inflating: train/train/malignant/ca_train_1736.jpg
#   inflating: train/train/malignant/ca_train_1737.jpg
#   inflating: train/train/malignant/ca_train_1738.jpg
#   inflating: train/train/malignant/ca_train_1739.jpg
#   inflating: train/train/malignant/ca_train_174.jpg
#   inflating: train/train/malignant/ca_train_1740.jpg
#   inflating: train/train/malignant/ca_train_1741.jpg
#   inflating: train/train/malignant/ca_train_1742.jpg
#   inflating: train/train/malignant/ca_train_1743.jpg
#   inflating: train/train/malignant/ca_train_1744.jpg
#   inflating: train/train/malignant/ca_train_1745.jpg
#   inflating: train/train/malignant/ca_train_1746.jpg
#   inflating: train/train/malignant/ca_train_1747.jpg
#   inflating: train/train/malignant/ca_train_1748.jpg
#   inflating: train/train/malignant/ca_train_1749.jpg
#   inflating: train/train/malignant/ca_train_175.jpg
#   inflating: train/train/malignant/ca_train_1750.jpg
#   inflating: train/train/malignant/ca_train_1751.jpg
#   inflating: train/train/malignant/ca_train_1752.jpg
#   inflating: train/train/malignant/ca_train_1753.jpg
#   inflating: train/train/malignant/ca_train_1754.jpg
#   inflating: train/train/malignant/ca_train_1755.jpg
#   inflating: train/train/malignant/ca_train_1756.jpg
#   inflating: train/train/malignant/ca_train_1757.jpg
#   inflating: train/train/malignant/ca_train_1758.jpg
#   inflating: train/train/malignant/ca_train_1759.jpg
#   inflating: train/train/malignant/ca_train_176.jpg
#   inflating: train/train/malignant/ca_train_1760.jpg
#   inflating: train/train/malignant/ca_train_1761.jpg
#   inflating: train/train/malignant/ca_train_1762.jpg
#   inflating: train/train/malignant/ca_train_1763.jpg
#   inflating: train/train/malignant/ca_train_1764.jpg
#   inflating: train/train/malignant/ca_train_1765.jpg
#   inflating: train/train/malignant/ca_train_1766.jpg
#   inflating: train/train/malignant/ca_train_1767.jpg
#   inflating: train/train/malignant/ca_train_1768.jpg
#   inflating: train/train/malignant/ca_train_1769.jpg
#   inflating: train/train/malignant/ca_train_177.jpg
#   inflating: train/train/malignant/ca_train_1770.jpg
#   inflating: train/train/malignant/ca_train_1771.jpg
#   inflating: train/train/malignant/ca_train_1772.jpg
#   inflating: train/train/malignant/ca_train_1773.jpg
#   inflating: train/train/malignant/ca_train_1774.jpg
#   inflating: train/train/malignant/ca_train_1775.jpg
#   inflating: train/train/malignant/ca_train_1776.jpg
#   inflating: train/train/malignant/ca_train_1777.jpg
#   inflating: train/train/malignant/ca_train_1778.jpg
#   inflating: train/train/malignant/ca_train_1779.jpg
#   inflating: train/train/malignant/ca_train_178.jpg
#   inflating: train/train/malignant/ca_train_1780.jpg
#   inflating: train/train/malignant/ca_train_1781.jpg
#   inflating: train/train/malignant/ca_train_1782.jpg
#   inflating: train/train/malignant/ca_train_1783.jpg
#   inflating: train/train/malignant/ca_train_1784.jpg
#   inflating: train/train/malignant/ca_train_1785.jpg
#   inflating: train/train/malignant/ca_train_1786.jpg
#   inflating: train/train/malignant/ca_train_1787.jpg
#   inflating: train/train/malignant/ca_train_1788.jpg
#   inflating: train/train/malignant/ca_train_1789.jpg
#   inflating: train/train/malignant/ca_train_179.jpg
#   inflating: train/train/malignant/ca_train_1790.jpg
#   inflating: train/train/malignant/ca_train_1791.jpg
#   inflating: train/train/malignant/ca_train_1792.jpg
#   inflating: train/train/malignant/ca_train_1793.jpg
#   inflating: train/train/malignant/ca_train_1794.jpg
#   inflating: train/train/malignant/ca_train_1795.jpg
#   inflating: train/train/malignant/ca_train_1796.jpg
#   inflating: train/train/malignant/ca_train_1797.jpg
#   inflating: train/train/malignant/ca_train_1798.jpg
#   inflating: train/train/malignant/ca_train_1799.jpg
#   inflating: train/train/malignant/ca_train_18.jpg
#   inflating: train/train/malignant/ca_train_180.jpg
#   inflating: train/train/malignant/ca_train_1800.jpg
#   inflating: train/train/malignant/ca_train_1801.jpg
#   inflating: train/train/malignant/ca_train_1802.jpg
#   inflating: train/train/malignant/ca_train_1803.jpg
#   inflating: train/train/malignant/ca_train_1804.jpg
#   inflating: train/train/malignant/ca_train_1805.jpg
#   inflating: train/train/malignant/ca_train_1806.jpg
#   inflating: train/train/malignant/ca_train_1807.jpg
#   inflating: train/train/malignant/ca_train_1808.jpg
#   inflating: train/train/malignant/ca_train_1809.jpg
#   inflating: train/train/malignant/ca_train_181.jpg
#   inflating: train/train/malignant/ca_train_1810.jpg
#   inflating: train/train/malignant/ca_train_1811.jpg
#   inflating: train/train/malignant/ca_train_1812.jpg
#   inflating: train/train/malignant/ca_train_1813.jpg
#   inflating: train/train/malignant/ca_train_1814.jpg
#   inflating: train/train/malignant/ca_train_1815.jpg
#   inflating: train/train/malignant/ca_train_1816.jpg
#   inflating: train/train/malignant/ca_train_1817.jpg
#   inflating: train/train/malignant/ca_train_1818.jpg
#   inflating: train/train/malignant/ca_train_1819.jpg
# ...
#   inflating: train/train/malignant/ca_train_732.jpg
#   inflating: train/train/malignant/ca_train_733.jpg
#   inflating: train/train/malignant/ca_train_734.jpg
#   inflating: train/train/malignant/ca_train_735.jpg
#   inflating: train/train/malignant/ca_train_736.jpg
#   inflating: train/train/malignant/ca_train_737.jpg
#   inflating: train/train/malignant/ca_train_738.jpg
#   inflating: train/train/malignant/ca_train_739.jpg
#   inflating: train/train/malignant/ca_train_74.jpg
#   inflating: train/train/malignant/ca_train_740.jpg
#   inflating: train/train/malignant/ca_train_741.jpg
#   inflating: train/train/malignant/ca_train_742.jpg
#   inflating: train/train/malignant/ca_train_743.jpg
#   inflating: train/train/malignant/ca_train_744.jpg
#   inflating: train/train/malignant/ca_train_745.jpg
#   inflating: train/train/malignant/ca_train_746.jpg
#   inflating: train/train/malignant/ca_train_747.jpg
#   inflating: train/train/malignant/ca_train_748.jpg
#   inflating: train/train/malignant/ca_train_749.jpg
#   inflating: train/train/malignant/ca_train_75.jpg
#   inflating: train/train/malignant/ca_train_750.jpg
#   inflating: train/train/malignant/ca_train_751.jpg
#   inflating: train/train/malignant/ca_train_752.jpg
#   inflating: train/train/malignant/ca_train_753.jpg
#   inflating: train/train/malignant/ca_train_754.jpg
#   inflating: train/train/malignant/ca_train_755.jpg
#   inflating: train/train/malignant/ca_train_756.jpg
#   inflating: train/train/malignant/ca_train_757.jpg
#   inflating: train/train/malignant/ca_train_758.jpg
#   inflating: train/train/malignant/ca_train_759.jpg
#   inflating: train/train/malignant/ca_train_76.jpg
#   inflating: train/train/malignant/ca_train_760.jpg
#   inflating: train/train/malignant/ca_train_761.jpg
#   inflating: train/train/malignant/ca_train_762.jpg
#   inflating: train/train/malignant/ca_train_763.jpg
#   inflating: train/train/malignant/ca_train_764.jpg
#   inflating: train/train/malignant/ca_train_765.jpg
#   inflating: train/train/malignant/ca_train_766.jpg
#   inflating: train/train/malignant/ca_train_767.jpg
#   inflating: train/train/malignant/ca_train_768.jpg
#   inflating: train/train/malignant/ca_train_769.jpg
#   inflating: train/train/malignant/ca_train_77.jpg
#   inflating: train/train/malignant/ca_train_770.jpg
#   inflating: train/train/malignant/ca_train_771.jpg
#   inflating: train/train/malignant/ca_train_772.jpg
#   inflating: train/train/malignant/ca_train_773.jpg
#   inflating: train/train/malignant/ca_train_774.jpg
#   inflating: train/train/malignant/ca_train_775.jpg
#   inflating: train/train/malignant/ca_train_776.jpg
#   inflating: train/train/malignant/ca_train_777.jpg
#   inflating: train/train/malignant/ca_train_778.jpg
#   inflating: train/train/malignant/ca_train_779.jpg
#   inflating: train/train/malignant/ca_train_78.jpg
#   inflating: train/train/malignant/ca_train_780.jpg
#   inflating: train/train/malignant/ca_train_781.jpg
#   inflating: train/train/malignant/ca_train_782.jpg
#   inflating: train/train/malignant/ca_train_783.jpg
#   inflating: train/train/malignant/ca_train_784.jpg
#   inflating: train/train/malignant/ca_train_785.jpg
#   inflating: train/train/malignant/ca_train_786.jpg
#   inflating: train/train/malignant/ca_train_787.jpg
#   inflating: train/train/malignant/ca_train_788.jpg
#   inflating: train/train/malignant/ca_train_789.jpg
#   inflating: train/train/malignant/ca_train_79.jpg
#   inflating: train/train/malignant/ca_train_790.jpg
#   inflating: train/train/malignant/ca_train_791.jpg
#   inflating: train/train/malignant/ca_train_792.jpg
#   inflating: train/train/malignant/ca_train_793.jpg
#   inflating: train/train/malignant/ca_train_794.jpg
#   inflating: train/train/malignant/ca_train_795.jpg
#   inflating: train/train/malignant/ca_train_796.jpg
#   inflating: train/train/malignant/ca_train_797.jpg
#   inflating: train/train/malignant/ca_train_798.jpg
#   inflating: train/train/malignant/ca_train_799.jpg
#   inflating: train/train/malignant/ca_train_8.jpg
#   inflating: train/train/malignant/ca_train_80.jpg
#   inflating: train/train/malignant/ca_train_800.jpg
#   inflating: train/train/malignant/ca_train_801.jpg
#   inflating: train/train/malignant/ca_train_802.jpg
#   inflating: train/train/malignant/ca_train_803.jpg
#   inflating: train/train/malignant/ca_train_804.jpg
#   inflating: train/train/malignant/ca_train_805.jpg
#   inflating: train/train/malignant/ca_train_806.jpg
#   inflating: train/train/malignant/ca_train_807.jpg
#   inflating: train/train/malignant/ca_train_808.jpg
#   inflating: train/train/malignant/ca_train_809.jpg
#   inflating: train/train/malignant/ca_train_81.jpg
#   inflating: train/train/malignant/ca_train_810.jpg
#   inflating: train/train/malignant/ca_train_811.jpg
#   inflating: train/train/malignant/ca_train_812.jpg
#   inflating: train/train/malignant/ca_train_813.jpg
#   inflating: train/train/malignant/ca_train_814.jpg
#   inflating: train/train/malignant/ca_train_815.jpg
#   inflating: train/train/malignant/ca_train_816.jpg
#   inflating: train/train/malignant/ca_train_817.jpg
#   inflating: train/train/malignant/ca_train_818.jpg
#   inflating: train/train/malignant/ca_train_819.jpg
#   inflating: train/train/malignant/ca_train_82.jpg
#   inflating: train/train/malignant/ca_train_820.jpg
#   inflating: train/train/malignant/ca_train_821.jpg
#   inflating: train/train/malignant/ca_train_822.jpg
#   inflating: train/train/malignant/ca_train_823.jpg
#   inflating: train/train/malignant/ca_train_824.jpg
#   inflating: train/train/malignant/ca_train_825.jpg
#   inflating: train/train/malignant/ca_train_826.jpg
#   inflating: train/train/malignant/ca_train_827.jpg
#   inflating: train/train/malignant/ca_train_828.jpg
#   inflating: train/train/malignant/ca_train_829.jpg
#   inflating: train/train/malignant/ca_train_83.jpg
#   inflating: train/train/malignant/ca_train_830.jpg
#   inflating: train/train/malignant/ca_train_831.jpg
#   inflating: train/train/malignant/ca_train_832.jpg
#   inflating: train/train/malignant/ca_train_833.jpg
#   inflating: train/train/malignant/ca_train_834.jpg
#   inflating: train/train/malignant/ca_train_835.jpg
#   inflating: train/train/malignant/ca_train_836.jpg
#   inflating: train/train/malignant/ca_train_837.jpg
#   inflating: train/train/malignant/ca_train_838.jpg
#   inflating: train/train/malignant/ca_train_839.jpg
#   inflating: train/train/malignant/ca_train_84.jpg
#   inflating: train/train/malignant/ca_train_840.jpg
#   inflating: train/train/malignant/ca_train_841.jpg
#   inflating: train/train/malignant/ca_train_842.jpg
#   inflating: train/train/malignant/ca_train_843.jpg
#   inflating: train/train/malignant/ca_train_844.jpg
#   inflating: train/train/malignant/ca_train_845.jpg
#   inflating: train/train/malignant/ca_train_846.jpg
#   inflating: train/train/malignant/ca_train_847.jpg
#   inflating: train/train/malignant/ca_train_848.jpg
#   inflating: train/train/malignant/ca_train_849.jpg
#   inflating: train/train/malignant/ca_train_85.jpg
#   inflating: train/train/malignant/ca_train_850.jpg
#   inflating: train/train/malignant/ca_train_851.jpg
#   inflating: train/train/malignant/ca_train_852.jpg
#   inflating: train/train/malignant/ca_train_853.jpg
#   inflating: train/train/malignant/ca_train_854.jpg
#   inflating: train/train/malignant/ca_train_855.jpg
#   inflating: train/train/malignant/ca_train_856.jpg
#   inflating: train/train/malignant/ca_train_857.jpg
#   inflating: train/train/malignant/ca_train_858.jpg
#   inflating: train/train/malignant/ca_train_859.jpg
#   inflating: train/train/malignant/ca_train_86.jpg
#   inflating: train/train/malignant/ca_train_860.jpg
#   inflating: train/train/malignant/ca_train_861.jpg
#   inflating: train/train/malignant/ca_train_862.jpg
#   inflating: train/train/malignant/ca_train_863.jpg
#   inflating: train/train/malignant/ca_train_864.jpg
#   inflating: train/train/malignant/ca_train_865.jpg
#   inflating: train/train/malignant/ca_train_866.jpg
#   inflating: train/train/malignant/ca_train_867.jpg
#   inflating: train/train/malignant/ca_train_868.jpg
#   inflating: train/train/malignant/ca_train_869.jpg
#   inflating: train/train/malignant/ca_train_87.jpg
#   inflating: train/train/malignant/ca_train_870.jpg
#   inflating: train/train/malignant/ca_train_871.jpg
#   inflating: train/train/malignant/ca_train_872.jpg
#   inflating: train/train/malignant/ca_train_873.jpg
#   inflating: train/train/malignant/ca_train_874.jpg
#   inflating: train/train/malignant/ca_train_875.jpg
#   inflating: train/train/malignant/ca_train_876.jpg
#   inflating: train/train/malignant/ca_train_877.jpg
#   inflating: train/train/malignant/ca_train_878.jpg
#   inflating: train/train/malignant/ca_train_879.jpg
#   inflating: train/train/malignant/ca_train_88.jpg
#   inflating: train/train/malignant/ca_train_880.jpg
#   inflating: train/train/malignant/ca_train_881.jpg
#   inflating: train/train/malignant/ca_train_882.jpg
#   inflating: train/train/malignant/ca_train_883.jpg
#   inflating: train/train/malignant/ca_train_884.jpg
#   inflating: train/train/malignant/ca_train_885.jpg
#   inflating: train/train/malignant/ca_train_886.jpg
#   inflating: train/train/malignant/ca_train_887.jpg
#   inflating: train/train/malignant/ca_train_888.jpg
#   inflating: train/train/malignant/ca_train_889.jpg
#   inflating: train/train/malignant/ca_train_89.jpg
#   inflating: train/train/malignant/ca_train_890.jpg
#   inflating: train/train/malignant/ca_train_891.jpg
#   inflating: train/train/malignant/ca_train_892.jpg
#   inflating: train/train/malignant/ca_train_893.jpg
#   inflating: train/train/malignant/ca_train_894.jpg
#   inflating: train/train/malignant/ca_train_895.jpg
#   inflating: train/train/malignant/ca_train_896.jpg
#   inflating: train/train/malignant/ca_train_897.jpg
#   inflating: train/train/malignant/ca_train_898.jpg
#   inflating: train/train/malignant/ca_train_899.jpg
#   inflating: train/train/malignant/ca_train_9.jpg
#   inflating: train/train/malignant/ca_train_90.jpg
#   inflating: train/train/malignant/ca_train_900.jpg
#   inflating: train/train/malignant/ca_train_901.jpg
#   inflating: train/train/malignant/ca_train_902.jpg
#   inflating: train/train/malignant/ca_train_903.jpg
#   inflating: train/train/malignant/ca_train_904.jpg
#   inflating: train/train/malignant/ca_train_905.jpg
#   inflating: train/train/malignant/ca_train_906.jpg
#   inflating: train/train/malignant/ca_train_907.jpg
#   inflating: train/train/malignant/ca_train_908.jpg
#   inflating: train/train/malignant/ca_train_909.jpg
#   inflating: train/train/malignant/ca_train_91.jpg
#   inflating: train/train/malignant/ca_train_910.jpg
#   inflating: train/train/malignant/ca_train_911.jpg
#   inflating: train/train/malignant/ca_train_912.jpg
#   inflating: train/train/malignant/ca_train_913.jpg
#   inflating: train/train/malignant/ca_train_914.jpg
#   inflating: train/train/malignant/ca_train_915.jpg
#   inflating: train/train/malignant/ca_train_916.jpg
#   inflating: train/train/malignant/ca_train_917.jpg
#   inflating: train/train/malignant/ca_train_918.jpg
#   inflating: train/train/malignant/ca_train_919.jpg
#   inflating: train/train/malignant/ca_train_92.jpg
#   inflating: train/train/malignant/ca_train_920.jpg
#   inflating: train/train/malignant/ca_train_921.jpg
#   inflating: train/train/malignant/ca_train_922.jpg
#   inflating: train/train/malignant/ca_train_923.jpg
#   inflating: train/train/malignant/ca_train_924.jpg
#   inflating: train/train/malignant/ca_train_925.jpg
#   inflating: train/train/malignant/ca_train_926.jpg
#   inflating: train/train/malignant/ca_train_927.jpg
#   inflating: train/train/malignant/ca_train_928.jpg
#   inflating: train/train/malignant/ca_train_929.jpg
#   inflating: train/train/malignant/ca_train_93.jpg
#   inflating: train/train/malignant/ca_train_930.jpg
#   inflating: train/train/malignant/ca_train_931.jpg
#   inflating: train/train/malignant/ca_train_932.jpg
#   inflating: train/train/malignant/ca_train_933.jpg
#   inflating: train/train/malignant/ca_train_934.jpg
#   inflating: train/train/malignant/ca_train_935.jpg
#   inflating: train/train/malignant/ca_train_936.jpg
#   inflating: train/train/malignant/ca_train_937.jpg
#   inflating: train/train/malignant/ca_train_938.jpg
#   inflating: train/train/malignant/ca_train_939.jpg
#   inflating: train/train/malignant/ca_train_94.jpg
#   inflating: train/train/malignant/ca_train_940.jpg
#   inflating: train/train/malignant/ca_train_941.jpg
#   inflating: train/train/malignant/ca_train_942.jpg
#   inflating: train/train/malignant/ca_train_943.jpg
#   inflating: train/train/malignant/ca_train_944.jpg
#   inflating: train/train/malignant/ca_train_945.jpg
#   inflating: train/train/malignant/ca_train_946.jpg
#   inflating: train/train/malignant/ca_train_947.jpg
#   inflating: train/train/malignant/ca_train_948.jpg
#   inflating: train/train/malignant/ca_train_949.jpg
#   inflating: train/train/malignant/ca_train_95.jpg
#   inflating: train/train/malignant/ca_train_950.jpg
#   inflating: train/train/malignant/ca_train_951.jpg
#   inflating: train/train/malignant/ca_train_952.jpg
#   inflating: train/train/malignant/ca_train_953.jpg
#   inflating: train/train/malignant/ca_train_954.jpg
#   inflating: train/train/malignant/ca_train_955.jpg
#   inflating: train/train/malignant/ca_train_956.jpg
#   inflating: train/train/malignant/ca_train_957.jpg
#   inflating: train/train/malignant/ca_train_958.jpg
#   inflating: train/train/malignant/ca_train_959.jpg
#   inflating: train/train/malignant/ca_train_96.jpg
#   inflating: train/train/malignant/ca_train_960.jpg
#   inflating: train/train/malignant/ca_train_961.jpg
#   inflating: train/train/malignant/ca_train_962.jpg
#   inflating: train/train/malignant/ca_train_963.jpg
#   inflating: train/train/malignant/ca_train_964.jpg
#   inflating: train/train/malignant/ca_train_965.jpg
#   inflating: train/train/malignant/ca_train_966.jpg
#   inflating: train/train/malignant/ca_train_967.jpg
#   inflating: train/train/malignant/ca_train_968.jpg
#   inflating: train/train/malignant/ca_train_969.jpg
#   inflating: train/train/malignant/ca_train_97.jpg
#   inflating: train/train/malignant/ca_train_970.jpg
#   inflating: train/train/malignant/ca_train_971.jpg
#   inflating: train/train/malignant/ca_train_972.jpg
#   inflating: train/train/malignant/ca_train_973.jpg
#   inflating: train/train/malignant/ca_train_974.jpg
#   inflating: train/train/malignant/ca_train_975.jpg
#   inflating: train/train/malignant/ca_train_976.jpg
#   inflating: train/train/malignant/ca_train_977.jpg
#   inflating: train/train/malignant/ca_train_978.jpg
#   inflating: train/train/malignant/ca_train_979.jpg
#   inflating: train/train/malignant/ca_train_98.jpg
#   inflating: train/train/malignant/ca_train_980.jpg
#   inflating: train/train/malignant/ca_train_981.jpg
#   inflating: train/train/malignant/ca_train_982.jpg
#   inflating: train/train/malignant/ca_train_983.jpg
#   inflating: train/train/malignant/ca_train_984.jpg
#   inflating: train/train/malignant/ca_train_985.jpg
#   inflating: train/train/malignant/ca_train_986.jpg
#   inflating: train/train/malignant/ca_train_987.jpg
#   inflating: train/train/malignant/ca_train_988.jpg
#   inflating: train/train/malignant/ca_train_989.jpg
#   inflating: train/train/malignant/ca_train_99.jpg
#   inflating: train/train/malignant/ca_train_990.jpg
#   inflating: train/train/malignant/ca_train_991.jpg
#   inflating: train/train/malignant/ca_train_992.jpg
#   inflating: train/train/malignant/ca_train_993.jpg
#   inflating: train/train/malignant/ca_train_994.jpg
#   inflating: train/train/malignant/ca_train_995.jpg
#   inflating: train/train/malignant/ca_train_996.jpg
#   inflating: train/train/malignant/ca_train_997.jpg
#   inflating: train/train/malignant/ca_train_998.jpg
#   inflating: train/train/malignant/ca_train_999.jpg

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import get_file
from sklearn.metrics import roc_curve, auc, confusion_matrix
from imblearn.metrics import sensitivity_score, specificity_score

import os
import glob
import zipfile
import random

import shutil
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import img_to_array, load_img

# %%
os.mkdir("newtrain")
train = os.path.join("newtrain", "train")
valid = os.path.join("newtrain", "valid")
os.mkdir(train)
os.mkdir(valid)
train_benign = os.path.join("newtrain/train", "benign")
train_malignant = os.path.join("newtrain/train", "malignant")
valid_benign = os.path.join("newtrain/valid", "benign")
valid_malignant = os.path.join("newtrain/valid", "malignant")
os.mkdir(train_benign)
os.mkdir(train_malignant)
os.mkdir(valid_benign)
os.mkdir(valid_malignant)

# %%
num_test = len(os.listdir('/content/test/test/malignant'))
num_test
# Out:
# 265

# %%
#os.mkdir("test")
test_benign = os.path.join('test', "benign")
test_ca = os.path.join('test', 'malignant')
os.mkdir(test_benign)
os.mkdir(test_ca)

# %%
name_test_ca = list(os.listdir('/content/test/test/malignant'))
name_test_benign = list(os.listdir('/content/test/test/benign'))

# %%
random.shuffle(name_test_benign)
test_benign = name_test_benign[:num_test]

# %%
len(name_test_benign)
# Out:
# 1600

# %%
for name_ca in name_test_ca:
    path = '/content/test/test/malignant/'
    shutil.copy(path+name_ca, '/content/test/malignant/')
for name_nonca in test_benign:
    path = '/content/test/test/benign/'
    shutil.copy(path+name_nonca, '/content/test/benign/')

# %%
test_ca = len(os.listdir('/content/test/malignant/'))
test_nonca = len(os.listdir('/content/test/benign/'))

# %%
name_ca = list(os.listdir('/content/train/train/malignant'))
len(name_ca)
# Out:
# 5040

# %%
valid_size = 0.1 
valid_number = int(len(name_ca) * valid_size)
random.shuffle(name_ca)
valid_set_ca = name_ca[:valid_number]
train_set_ca = name_ca[valid_number:]
name_nonca = list(os.listdir('/content/train/train/benign'))
random.shuffle(name_nonca)
valid_set_nonca = name_nonca[:valid_number]
train_set_nonca = name_nonca[valid_number:5040]

# %%
print(f"valid for ca = {len(valid_set_ca)}")
print(f"valid for nonca = {len(valid_set_nonca)} ")
print(f"train for ca = {len(train_set_ca)}")
print(f"train for nonca = {len(train_set_nonca)} ")
print(f"test for ca = {test_ca}")
print(f"test for nonca = {test_nonca}")
# Out:
# valid for ca = 504
# valid for nonca = 504
# train for ca = 4536
# train for nonca = 4536
# test for ca = 265
# test for nonca = 265

# %%
for ca in valid_set_ca:
    path = '/content/train/train/malignant/'
    shutil.copy(path+ca, '/content/newtrain/valid/malignant/')
for ca in train_set_ca:
    path = '/content/train/train/malignant/'
    shutil.copy(path+ca, '/content/newtrain/train/malignant/')
for nonca in valid_set_nonca:
    path = '/content/train/train/benign/'
    shutil.copy(path+nonca, '/content/newtrain/valid/benign/')
for nonca in train_set_nonca:
    path = '/content/train/train/benign/'
    shutil.copy(path+nonca, '/content/newtrain/train/benign/')

# %%
train_dir = '/content/newtrain/train'
valid_dir = '/content/newtrain/valid'

# %%
img_height = 256
img_width = 256
batch_size_16 = 16
train_ds = tf.keras.utils.image_dataset_from_directory(
          train_dir,
          image_size=(img_height, img_width),
          batch_size=batch_size_16)

valid_ds = tf.keras.utils.image_dataset_from_directory(
          valid_dir,
          image_size=(img_height, img_width),
          batch_size=batch_size_16)
# Out:
# Found 9072 files belonging to 2 classes.
# Found 1008 files belonging to 2 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['benign', 'malignant']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %%
import keras
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2)    
  ]
)

resize_and_rescale = tf.keras.Sequential([
    #layers.CenterCrop(CCrop,CCrop),
    #layers.Resizing(512, 512),
    layers.Rescaling(1./255.)
])

# %%
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from keras.applications import ResNet50V2
pre_trained_model = ResNet50V2(include_top = False,weights = 'imagenet')
    
for layer in pre_trained_model.layers:
  layer.trainable = False
pre_trained_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 5s 0us/step
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1_pad (ZeroPadding2D)      (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  conv1_conv (Conv2D)            (None, None, None,   9472        ['conv1_pad[0][0]']
#                                 64)
#
#  pool1_pad (ZeroPadding2D)      (None, None, None,   0           ['conv1_conv[0][0]']
#                                 64)
#
#  pool1_pool (MaxPooling2D)      (None, None, None,   0           ['pool1_pad[0][0]']
#                                 64)
#
#  conv2_block1_preact_bn (BatchN  (None, None, None,   256        ['pool1_pool[0][0]']
#  ormalization)                  64)
#
#  conv2_block1_preact_relu (Acti  (None, None, None,   0          ['conv2_block1_preact_bn[0][0]']
#  vation)                        64)
#
#  conv2_block1_1_conv (Conv2D)   (None, None, None,   4096        ['conv2_block1_preact_relu[0][0]'
#                                 64)                              ]
#
#  conv2_block1_1_bn (BatchNormal  (None, None, None,   256        ['conv2_block1_1_conv[0][0]']
#  ization)                       64)
#
#  conv2_block1_1_relu (Activatio  (None, None, None,   0          ['conv2_block1_1_bn[0][0]']
#  n)                             64)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, None, None,   0          ['conv2_block1_1_relu[0][0]']
#  g2D)                           64)
#
#  conv2_block1_2_conv (Conv2D)   (None, None, None,   36864       ['conv2_block1_2_pad[0][0]']
#                                 64)
#
#  conv2_block1_2_bn (BatchNormal  (None, None, None,   256        ['conv2_block1_2_conv[0][0]']
#  ization)                       64)
#
#  conv2_block1_2_relu (Activatio  (None, None, None,   0          ['conv2_block1_2_bn[0][0]']
#  n)                             64)
#
#  conv2_block1_0_conv (Conv2D)   (None, None, None,   16640       ['conv2_block1_preact_relu[0][0]'
#                                 256)                             ]
#
#  conv2_block1_3_conv (Conv2D)   (None, None, None,   16640       ['conv2_block1_2_relu[0][0]']
#                                 256)
#
#  conv2_block1_out (Add)         (None, None, None,   0           ['conv2_block1_0_conv[0][0]',
#                                 256)                              'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, None, None,   1024       ['conv2_block1_out[0][0]']
#  ormalization)                  256)
#
#  conv2_block2_preact_relu (Acti  (None, None, None,   0          ['conv2_block2_preact_bn[0][0]']
#  vation)                        256)
#
#  conv2_block2_1_conv (Conv2D)   (None, None, None,   16384       ['conv2_block2_preact_relu[0][0]'
#                                 64)                              ]
#
#  conv2_block2_1_bn (BatchNormal  (None, None, None,   256        ['conv2_block2_1_conv[0][0]']
#  ization)                       64)
#
#  conv2_block2_1_relu (Activatio  (None, None, None,   0          ['conv2_block2_1_bn[0][0]']
#  n)                             64)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, None, None,   0          ['conv2_block2_1_relu[0][0]']
#  g2D)                           64)
#
#  conv2_block2_2_conv (Conv2D)   (None, None, None,   36864       ['conv2_block2_2_pad[0][0]']
#                                 64)
#
#  conv2_block2_2_bn (BatchNormal  (None, None, None,   256        ['conv2_block2_2_conv[0][0]']
#  ization)                       64)
#
#  conv2_block2_2_relu (Activatio  (None, None, None,   0          ['conv2_block2_2_bn[0][0]']
#  n)                             64)
#
#  conv2_block2_3_conv (Conv2D)   (None, None, None,   16640       ['conv2_block2_2_relu[0][0]']
#                                 256)
#
#  conv2_block2_out (Add)         (None, None, None,   0           ['conv2_block1_out[0][0]',
#                                 256)                              'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, None, None,   1024       ['conv2_block2_out[0][0]']
#  ormalization)                  256)
#
#  conv2_block3_preact_relu (Acti  (None, None, None,   0          ['conv2_block3_preact_bn[0][0]']
#  vation)                        256)
#
#  conv2_block3_1_conv (Conv2D)   (None, None, None,   16384       ['conv2_block3_preact_relu[0][0]'
#                                 64)                              ]
#
#  conv2_block3_1_bn (BatchNormal  (None, None, None,   256        ['conv2_block3_1_conv[0][0]']
#  ization)                       64)
#
#  conv2_block3_1_relu (Activatio  (None, None, None,   0          ['conv2_block3_1_bn[0][0]']
#  n)                             64)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, None, None,   0          ['conv2_block3_1_relu[0][0]']
#  g2D)                           64)
#
#  conv2_block3_2_conv (Conv2D)   (None, None, None,   36864       ['conv2_block3_2_pad[0][0]']
#                                 64)
#
#  conv2_block3_2_bn (BatchNormal  (None, None, None,   256        ['conv2_block3_2_conv[0][0]']
#  ization)                       64)
#
#  conv2_block3_2_relu (Activatio  (None, None, None,   0          ['conv2_block3_2_bn[0][0]']
#  n)                             64)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['conv2_block2_out[0][0]']
#                                 256)
#
#  conv2_block3_3_conv (Conv2D)   (None, None, None,   16640       ['conv2_block3_2_relu[0][0]']
#                                 256)
#
#  conv2_block3_out (Add)         (None, None, None,   0           ['max_pooling2d[0][0]',
#                                 256)                              'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, None, None,   1024       ['conv2_block3_out[0][0]']
#  ormalization)                  256)
#
#  conv3_block1_preact_relu (Acti  (None, None, None,   0          ['conv3_block1_preact_bn[0][0]']
#  vation)                        256)
#
#  conv3_block1_1_conv (Conv2D)   (None, None, None,   32768       ['conv3_block1_preact_relu[0][0]'
#                                 128)                             ]
#
#  conv3_block1_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block1_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block1_1_relu (Activatio  (None, None, None,   0          ['conv3_block1_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, None, None,   0          ['conv3_block1_1_relu[0][0]']
#  g2D)                           128)
#
#  conv3_block1_2_conv (Conv2D)   (None, None, None,   147456      ['conv3_block1_2_pad[0][0]']
#                                 128)
#
#  conv3_block1_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block1_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block1_2_relu (Activatio  (None, None, None,   0          ['conv3_block1_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block1_0_conv (Conv2D)   (None, None, None,   131584      ['conv3_block1_preact_relu[0][0]'
#                                 512)                             ]
#
#  conv3_block1_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block1_2_relu[0][0]']
#                                 512)
#
#  conv3_block1_out (Add)         (None, None, None,   0           ['conv3_block1_0_conv[0][0]',
#                                 512)                              'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, None, None,   2048       ['conv3_block1_out[0][0]']
#  ormalization)                  512)
#
#  conv3_block2_preact_relu (Acti  (None, None, None,   0          ['conv3_block2_preact_bn[0][0]']
#  vation)                        512)
#
#  conv3_block2_1_conv (Conv2D)   (None, None, None,   65536       ['conv3_block2_preact_relu[0][0]'
#                                 128)                             ]
#
#  conv3_block2_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block2_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block2_1_relu (Activatio  (None, None, None,   0          ['conv3_block2_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, None, None,   0          ['conv3_block2_1_relu[0][0]']
#  g2D)                           128)
#
#  conv3_block2_2_conv (Conv2D)   (None, None, None,   147456      ['conv3_block2_2_pad[0][0]']
#                                 128)
#
#  conv3_block2_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block2_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block2_2_relu (Activatio  (None, None, None,   0          ['conv3_block2_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block2_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block2_2_relu[0][0]']
#                                 512)
#
#  conv3_block2_out (Add)         (None, None, None,   0           ['conv3_block1_out[0][0]',
#                                 512)                              'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, None, None,   2048       ['conv3_block2_out[0][0]']
#  ormalization)                  512)
#
#  conv3_block3_preact_relu (Acti  (None, None, None,   0          ['conv3_block3_preact_bn[0][0]']
#  vation)                        512)
#
#  conv3_block3_1_conv (Conv2D)   (None, None, None,   65536       ['conv3_block3_preact_relu[0][0]'
#                                 128)                             ]
#
#  conv3_block3_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block3_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block3_1_relu (Activatio  (None, None, None,   0          ['conv3_block3_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, None, None,   0          ['conv3_block3_1_relu[0][0]']
#  g2D)                           128)
#
#  conv3_block3_2_conv (Conv2D)   (None, None, None,   147456      ['conv3_block3_2_pad[0][0]']
#                                 128)
#
#  conv3_block3_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block3_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block3_2_relu (Activatio  (None, None, None,   0          ['conv3_block3_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block3_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block3_2_relu[0][0]']
#                                 512)
#
#  conv3_block3_out (Add)         (None, None, None,   0           ['conv3_block2_out[0][0]',
#                                 512)                              'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, None, None,   2048       ['conv3_block3_out[0][0]']
#  ormalization)                  512)
#
#  conv3_block4_preact_relu (Acti  (None, None, None,   0          ['conv3_block4_preact_bn[0][0]']
#  vation)                        512)
#
#  conv3_block4_1_conv (Conv2D)   (None, None, None,   65536       ['conv3_block4_preact_relu[0][0]'
#                                 128)                             ]
#
#  conv3_block4_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block4_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block4_1_relu (Activatio  (None, None, None,   0          ['conv3_block4_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, None, None,   0          ['conv3_block4_1_relu[0][0]']
#  g2D)                           128)
#
#  conv3_block4_2_conv (Conv2D)   (None, None, None,   147456      ['conv3_block4_2_pad[0][0]']
#                                 128)
#
#  conv3_block4_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block4_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block4_2_relu (Activatio  (None, None, None,   0          ['conv3_block4_2_bn[0][0]']
#  n)                             128)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['conv3_block3_out[0][0]']
#                                 512)
#
#  conv3_block4_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block4_2_relu[0][0]']
#                                 512)
#
#  conv3_block4_out (Add)         (None, None, None,   0           ['max_pooling2d_1[0][0]',
#                                 512)                              'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, None, None,   2048       ['conv3_block4_out[0][0]']
#  ormalization)                  512)
#
#  conv4_block1_preact_relu (Acti  (None, None, None,   0          ['conv4_block1_preact_bn[0][0]']
#  vation)                        512)
#
#  conv4_block1_1_conv (Conv2D)   (None, None, None,   131072      ['conv4_block1_preact_relu[0][0]'
#                                 256)                             ]
#
#  conv4_block1_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block1_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block1_1_relu (Activatio  (None, None, None,   0          ['conv4_block1_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, None, None,   0          ['conv4_block1_1_relu[0][0]']
#  g2D)                           256)
#
#  conv4_block1_2_conv (Conv2D)   (None, None, None,   589824      ['conv4_block1_2_pad[0][0]']
#                                 256)
#
#  conv4_block1_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block1_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block1_2_relu (Activatio  (None, None, None,   0          ['conv4_block1_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block1_0_conv (Conv2D)   (None, None, None,   525312      ['conv4_block1_preact_relu[0][0]'
#                                 1024)                            ]
#
#  conv4_block1_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block1_2_relu[0][0]']
#                                 1024)
#
#  conv4_block1_out (Add)         (None, None, None,   0           ['conv4_block1_0_conv[0][0]',
#                                 1024)                             'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, None, None,   4096       ['conv4_block1_out[0][0]']
#  ormalization)                  1024)
#
#  conv4_block2_preact_relu (Acti  (None, None, None,   0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        1024)
#
#  conv4_block2_1_conv (Conv2D)   (None, None, None,   262144      ['conv4_block2_preact_relu[0][0]'
#                                 256)                             ]
#
#  conv4_block2_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block2_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block2_1_relu (Activatio  (None, None, None,   0          ['conv4_block2_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, None, None,   0          ['conv4_block2_1_relu[0][0]']
#  g2D)                           256)
#
#  conv4_block2_2_conv (Conv2D)   (None, None, None,   589824      ['conv4_block2_2_pad[0][0]']
#                                 256)
#
#  conv4_block2_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block2_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block2_2_relu (Activatio  (None, None, None,   0          ['conv4_block2_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block2_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block2_2_relu[0][0]']
#                                 1024)
#
#  conv4_block2_out (Add)         (None, None, None,   0           ['conv4_block1_out[0][0]',
#                                 1024)                             'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, None, None,   4096       ['conv4_block2_out[0][0]']
#  ormalization)                  1024)
#
#  conv4_block3_preact_relu (Acti  (None, None, None,   0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        1024)
#
#  conv4_block3_1_conv (Conv2D)   (None, None, None,   262144      ['conv4_block3_preact_relu[0][0]'
#                                 256)                             ]
#
#  conv4_block3_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block3_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block3_1_relu (Activatio  (None, None, None,   0          ['conv4_block3_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, None, None,   0          ['conv4_block3_1_relu[0][0]']
#  g2D)                           256)
#
#  conv4_block3_2_conv (Conv2D)   (None, None, None,   589824      ['conv4_block3_2_pad[0][0]']
#                                 256)
#
#  conv4_block3_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block3_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block3_2_relu (Activatio  (None, None, None,   0          ['conv4_block3_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block3_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block3_2_relu[0][0]']
#                                 1024)
#
#  conv4_block3_out (Add)         (None, None, None,   0           ['conv4_block2_out[0][0]',
#                                 1024)                             'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, None, None,   4096       ['conv4_block3_out[0][0]']
#  ormalization)                  1024)
#
#  conv4_block4_preact_relu (Acti  (None, None, None,   0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        1024)
#
#  conv4_block4_1_conv (Conv2D)   (None, None, None,   262144      ['conv4_block4_preact_relu[0][0]'
#                                 256)                             ]
#
#  conv4_block4_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block4_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block4_1_relu (Activatio  (None, None, None,   0          ['conv4_block4_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, None, None,   0          ['conv4_block4_1_relu[0][0]']
#  g2D)                           256)
#
#  conv4_block4_2_conv (Conv2D)   (None, None, None,   589824      ['conv4_block4_2_pad[0][0]']
#                                 256)
#
#  conv4_block4_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block4_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block4_2_relu (Activatio  (None, None, None,   0          ['conv4_block4_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block4_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block4_2_relu[0][0]']
#                                 1024)
#
#  conv4_block4_out (Add)         (None, None, None,   0           ['conv4_block3_out[0][0]',
#                                 1024)                             'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, None, None,   4096       ['conv4_block4_out[0][0]']
#  ormalization)                  1024)
#
#  conv4_block5_preact_relu (Acti  (None, None, None,   0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        1024)
#
#  conv4_block5_1_conv (Conv2D)   (None, None, None,   262144      ['conv4_block5_preact_relu[0][0]'
#                                 256)                             ]
#
#  conv4_block5_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block5_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block5_1_relu (Activatio  (None, None, None,   0          ['conv4_block5_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, None, None,   0          ['conv4_block5_1_relu[0][0]']
#  g2D)                           256)
#
#  conv4_block5_2_conv (Conv2D)   (None, None, None,   589824      ['conv4_block5_2_pad[0][0]']
#                                 256)
#
#  conv4_block5_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block5_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block5_2_relu (Activatio  (None, None, None,   0          ['conv4_block5_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block5_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block5_2_relu[0][0]']
#                                 1024)
#
#  conv4_block5_out (Add)         (None, None, None,   0           ['conv4_block4_out[0][0]',
#                                 1024)                             'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, None, None,   4096       ['conv4_block5_out[0][0]']
#  ormalization)                  1024)
#
#  conv4_block6_preact_relu (Acti  (None, None, None,   0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        1024)
#
#  conv4_block6_1_conv (Conv2D)   (None, None, None,   262144      ['conv4_block6_preact_relu[0][0]'
#                                 256)                             ]
#
#  conv4_block6_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block6_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block6_1_relu (Activatio  (None, None, None,   0          ['conv4_block6_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, None, None,   0          ['conv4_block6_1_relu[0][0]']
#  g2D)                           256)
#
#  conv4_block6_2_conv (Conv2D)   (None, None, None,   589824      ['conv4_block6_2_pad[0][0]']
#                                 256)
#
#  conv4_block6_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block6_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block6_2_relu (Activatio  (None, None, None,   0          ['conv4_block6_2_bn[0][0]']
#  n)                             256)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['conv4_block5_out[0][0]']
#                                 1024)
#
#  conv4_block6_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block6_2_relu[0][0]']
#                                 1024)
#
#  conv4_block6_out (Add)         (None, None, None,   0           ['max_pooling2d_2[0][0]',
#                                 1024)                             'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, None, None,   4096       ['conv4_block6_out[0][0]']
#  ormalization)                  1024)
#
#  conv5_block1_preact_relu (Acti  (None, None, None,   0          ['conv5_block1_preact_bn[0][0]']
#  vation)                        1024)
#
#  conv5_block1_1_conv (Conv2D)   (None, None, None,   524288      ['conv5_block1_preact_relu[0][0]'
#                                 512)                             ]
#
#  conv5_block1_1_bn (BatchNormal  (None, None, None,   2048       ['conv5_block1_1_conv[0][0]']
#  ization)                       512)
#
#  conv5_block1_1_relu (Activatio  (None, None, None,   0          ['conv5_block1_1_bn[0][0]']
#  n)                             512)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, None, None,   0          ['conv5_block1_1_relu[0][0]']
#  g2D)                           512)
#
#  conv5_block1_2_conv (Conv2D)   (None, None, None,   2359296     ['conv5_block1_2_pad[0][0]']
#                                 512)
#
#  conv5_block1_2_bn (BatchNormal  (None, None, None,   2048       ['conv5_block1_2_conv[0][0]']
#  ization)                       512)
#
#  conv5_block1_2_relu (Activatio  (None, None, None,   0          ['conv5_block1_2_bn[0][0]']
#  n)                             512)
#
#  conv5_block1_0_conv (Conv2D)   (None, None, None,   2099200     ['conv5_block1_preact_relu[0][0]'
#                                 2048)                            ]
#
#  conv5_block1_3_conv (Conv2D)   (None, None, None,   1050624     ['conv5_block1_2_relu[0][0]']
#                                 2048)
#
#  conv5_block1_out (Add)         (None, None, None,   0           ['conv5_block1_0_conv[0][0]',
#                                 2048)                             'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, None, None,   8192       ['conv5_block1_out[0][0]']
#  ormalization)                  2048)
#
#  conv5_block2_preact_relu (Acti  (None, None, None,   0          ['conv5_block2_preact_bn[0][0]']
#  vation)                        2048)
#
#  conv5_block2_1_conv (Conv2D)   (None, None, None,   1048576     ['conv5_block2_preact_relu[0][0]'
#                                 512)                             ]
#
#  conv5_block2_1_bn (BatchNormal  (None, None, None,   2048       ['conv5_block2_1_conv[0][0]']
#  ization)                       512)
#
#  conv5_block2_1_relu (Activatio  (None, None, None,   0          ['conv5_block2_1_bn[0][0]']
#  n)                             512)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, None, None,   0          ['conv5_block2_1_relu[0][0]']
#  g2D)                           512)
#
#  conv5_block2_2_conv (Conv2D)   (None, None, None,   2359296     ['conv5_block2_2_pad[0][0]']
#                                 512)
#
#  conv5_block2_2_bn (BatchNormal  (None, None, None,   2048       ['conv5_block2_2_conv[0][0]']
#  ization)                       512)
#
#  conv5_block2_2_relu (Activatio  (None, None, None,   0          ['conv5_block2_2_bn[0][0]']
#  n)                             512)
#
#  conv5_block2_3_conv (Conv2D)   (None, None, None,   1050624     ['conv5_block2_2_relu[0][0]']
#                                 2048)
#
#  conv5_block2_out (Add)         (None, None, None,   0           ['conv5_block1_out[0][0]',
#                                 2048)                             'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, None, None,   8192       ['conv5_block2_out[0][0]']
#  ormalization)                  2048)
#
#  conv5_block3_preact_relu (Acti  (None, None, None,   0          ['conv5_block3_preact_bn[0][0]']
#  vation)                        2048)
#
#  conv5_block3_1_conv (Conv2D)   (None, None, None,   1048576     ['conv5_block3_preact_relu[0][0]'
#                                 512)                             ]
#
#  conv5_block3_1_bn (BatchNormal  (None, None, None,   2048       ['conv5_block3_1_conv[0][0]']
#  ization)                       512)
#
#  conv5_block3_1_relu (Activatio  (None, None, None,   0          ['conv5_block3_1_bn[0][0]']
#  n)                             512)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, None, None,   0          ['conv5_block3_1_relu[0][0]']
#  g2D)                           512)
#
#  conv5_block3_2_conv (Conv2D)   (None, None, None,   2359296     ['conv5_block3_2_pad[0][0]']
#                                 512)
#
#  conv5_block3_2_bn (BatchNormal  (None, None, None,   2048       ['conv5_block3_2_conv[0][0]']
#  ization)                       512)
#
#  conv5_block3_2_relu (Activatio  (None, None, None,   0          ['conv5_block3_2_bn[0][0]']
#  n)                             512)
#
#  conv5_block3_3_conv (Conv2D)   (None, None, None,   1050624     ['conv5_block3_2_relu[0][0]']
#                                 2048)
#
#  conv5_block3_out (Add)         (None, None, None,   0           ['conv5_block2_out[0][0]',
#                                 2048)                             'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, None, None,   8192        ['conv5_block3_out[0][0]']
#                                 2048)
#
#  post_relu (Activation)         (None, None, None,   0           ['post_bn[0][0]']
#                                 2048)
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 0
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
my_callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",factor=0.1,patience=7, min_lr=0.000000001),
    tf.keras.callbacks.ModelCheckpoint(filepath='model_weight.h5',save_best_only=True, verbose=2),
    tf.keras.callbacks.EarlyStopping(patience=15),
    #tf.keras.callbacks.TensorBoard(log_dir='./logs'),
    
]

# %%
def custom_model(pre_trained_model, lr, input_shape):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = resize_and_rescale(x)
    x = pre_trained_model(x)
    x = layers.Flatten()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(1, activation='sigmoid')(x)
    model = Model(inputs = inputs,outputs= x)
    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=lr),
                 loss = 'binary_crossentropy',
                 metrics = ['accuracy'])
    return model

# %%
model = custom_model(pre_trained_model, 0.001, (256,256,3))

# %%
history = model.fit(train_ds,
                    validation_data = valid_ds,
                    epochs = 50,
                    verbose=1,
                    callbacks=my_callbacks)
# Out:
# Epoch 1/50
# 567/567 [==============================] - ETA: 0s - loss: 1.0519 - accuracy: 0.8259
# Epoch 1: val_loss improved from inf to 0.25763, saving model to model_weight.h5
# 567/567 [==============================] - 393s 662ms/step - loss: 1.0519 - accuracy: 0.8259 - val_loss: 0.2576 - val_accuracy: 0.8938 - lr: 0.0010
# Epoch 2/50
# 567/567 [==============================] - ETA: 0s - loss: 0.3710 - accuracy: 0.8652
# Epoch 2: val_loss improved from 0.25763 to 0.24056, saving model to model_weight.h5
# 567/567 [==============================] - 384s 670ms/step - loss: 0.3710 - accuracy: 0.8652 - val_loss: 0.2406 - val_accuracy: 0.9038 - lr: 0.0010
# Epoch 3/50
# 567/567 [==============================] - ETA: 0s - loss: 0.3234 - accuracy: 0.8740
# Epoch 3: val_loss did not improve from 0.24056
# 567/567 [==============================] - 377s 659ms/step - loss: 0.3234 - accuracy: 0.8740 - val_loss: 0.2674 - val_accuracy: 0.8978 - lr: 0.0010
# Epoch 4/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2995 - accuracy: 0.8791
# Epoch 4: val_loss improved from 0.24056 to 0.23817, saving model to model_weight.h5
# 567/567 [==============================] - 388s 678ms/step - loss: 0.2995 - accuracy: 0.8791 - val_loss: 0.2382 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 5/50
# 567/567 [==============================] - ETA: 0s - loss: 0.3014 - accuracy: 0.8821
# Epoch 5: val_loss improved from 0.23817 to 0.21748, saving model to model_weight.h5
# 567/567 [==============================] - 382s 668ms/step - loss: 0.3014 - accuracy: 0.8821 - val_loss: 0.2175 - val_accuracy: 0.9187 - lr: 0.0010
# Epoch 6/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2794 - accuracy: 0.8857
# Epoch 6: val_loss did not improve from 0.21748
# 567/567 [==============================] - 373s 650ms/step - loss: 0.2794 - accuracy: 0.8857 - val_loss: 0.2372 - val_accuracy: 0.9008 - lr: 0.0010
# Epoch 7/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.8865
# Epoch 7: val_loss did not improve from 0.21748
# 567/567 [==============================] - 374s 652ms/step - loss: 0.2847 - accuracy: 0.8865 - val_loss: 0.2771 - val_accuracy: 0.9028 - lr: 0.0010
# Epoch 8/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2860 - accuracy: 0.8876
# Epoch 8: val_loss did not improve from 0.21748
# 567/567 [==============================] - 377s 659ms/step - loss: 0.2860 - accuracy: 0.8876 - val_loss: 0.3161 - val_accuracy: 0.8958 - lr: 0.0010
# Epoch 9/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2876 - accuracy: 0.8875
# Epoch 9: val_loss did not improve from 0.21748
# 567/567 [==============================] - 372s 649ms/step - loss: 0.2876 - accuracy: 0.8875 - val_loss: 0.2704 - val_accuracy: 0.8968 - lr: 0.0010
# Epoch 10/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2720 - accuracy: 0.8900
# Epoch 10: val_loss did not improve from 0.21748
# 567/567 [==============================] - 373s 651ms/step - loss: 0.2720 - accuracy: 0.8900 - val_loss: 0.2529 - val_accuracy: 0.9077 - lr: 0.0010
# Epoch 11/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.8878
# Epoch 11: val_loss did not improve from 0.21748
# 567/567 [==============================] - 372s 649ms/step - loss: 0.2700 - accuracy: 0.8878 - val_loss: 0.2276 - val_accuracy: 0.9077 - lr: 0.0010
# Epoch 12/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.8919
# Epoch 12: val_loss did not improve from 0.21748
# 567/567 [==============================] - 373s 652ms/step - loss: 0.2635 - accuracy: 0.8919 - val_loss: 0.2252 - val_accuracy: 0.9137 - lr: 0.0010
# Epoch 13/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2268 - accuracy: 0.9013
# Epoch 13: val_loss did not improve from 0.21748
# 567/567 [==============================] - 375s 655ms/step - loss: 0.2268 - accuracy: 0.9013 - val_loss: 0.2301 - val_accuracy: 0.9177 - lr: 1.0000e-04
# Epoch 14/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2267 - accuracy: 0.9059
# Epoch 14: val_loss did not improve from 0.21748
# 567/567 [==============================] - 381s 664ms/step - loss: 0.2267 - accuracy: 0.9059 - val_loss: 0.2204 - val_accuracy: 0.9167 - lr: 1.0000e-04
# Epoch 15/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9071
# Epoch 15: val_loss did not improve from 0.21748
# 567/567 [==============================] - 377s 659ms/step - loss: 0.2220 - accuracy: 0.9071 - val_loss: 0.2253 - val_accuracy: 0.9167 - lr: 1.0000e-04
# Epoch 16/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2136 - accuracy: 0.9149
# Epoch 16: val_loss did not improve from 0.21748
# 567/567 [==============================] - 376s 658ms/step - loss: 0.2136 - accuracy: 0.9149 - val_loss: 0.2253 - val_accuracy: 0.9157 - lr: 1.0000e-04
# Epoch 17/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2154 - accuracy: 0.9091
# Epoch 17: val_loss did not improve from 0.21748
# 567/567 [==============================] - 378s 660ms/step - loss: 0.2154 - accuracy: 0.9091 - val_loss: 0.2268 - val_accuracy: 0.9117 - lr: 1.0000e-04
# Epoch 18/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2068 - accuracy: 0.9147
# Epoch 18: val_loss did not improve from 0.21748
# 567/567 [==============================] - 402s 702ms/step - loss: 0.2068 - accuracy: 0.9147 - val_loss: 0.2363 - val_accuracy: 0.9167 - lr: 1.0000e-04
# Epoch 19/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9160
# Epoch 19: val_loss did not improve from 0.21748
# 567/567 [==============================] - 384s 669ms/step - loss: 0.2080 - accuracy: 0.9160 - val_loss: 0.2275 - val_accuracy: 0.9187 - lr: 1.0000e-04
# Epoch 20/50
# 567/567 [==============================] - ETA: 0s - loss: 0.2120 - accuracy: 0.9114
# Epoch 20: val_loss did not improve from 0.21748
# 567/567 [==============================] - 380s 663ms/step - loss: 0.2120 - accuracy: 0.9114 - val_loss: 0.2276 - val_accuracy: 0.9177 - lr: 1.0000e-05

# %%
# %rm -rf /content/test/test

# %%
test_dir = '/content/test'

# %%
model.save('ResNet50.h5')

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc=0)
plt.figure()

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()



plt.show()

# %%
test = tf.keras.utils.image_dataset_from_directory(
          test_dir,
          image_size=(img_height, img_width),
          batch_size=batch_size_16)
# Out:
# Found 530 files belonging to 2 classes.

# %%
model.evaluate(test)
# Out:
# 34/34 [==============================] - 22s 491ms/step - loss: 0.2215 - accuracy: 0.9113
# [0.22145020961761475, 0.9113207459449768]

# %%
pred = []
label = []

# %%
from tensorflow.keras.utils import load_img
import matplotlib.pyplot as pl
from tensorflow.keras.utils import img_to_array

# %%
test_ca = os.listdir('/content/test/malignant')
test_nonca = os.listdir('/content/test/benign')

# %%
for name in test_ca:
    img_path = '/content/test/malignant/' + name
    img = load_img(img_path, target_size=(256, 256))
    img_array = img_to_array(img)
    #img_array = img_array/255.
    img_batch = np.expand_dims(img_array, axis=0)   
    predic = model.predict(img_batch)
    if predic < 0.5 :
        pred.append(0)
        label.append(1)
        
    else:
        pred.append(1)
        label.append(1)

# %%
for name in test_nonca:
    img_path = '/content/test/benign/' + name
    img = load_img(img_path, target_size=(256, 256))
    img_array = img_to_array(img)
    #img_array = img_array/255.
    img_batch = np.expand_dims(img_array, axis=0)   
    predic = model.predict(img_batch)
    if predic < 0.5 :
        pred.append(0)
        label.append(0)
        
    else:
        pred.append(1)
        label.append(0)

# %%
from sklearn.metrics import confusion_matrix, classification_report
from mlxtend.plotting import plot_confusion_matrix
print(classification_report(label, pred))
cm1 = confusion_matrix(label, pred)
plot_confusion_matrix(conf_mat=cm1,show_absolute=True,
                                show_normed=True,
                                colorbar=True,
                                )
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       265
#            1       0.94      0.88      0.91       265
#
#     accuracy                           0.91       530
#    macro avg       0.91      0.91      0.91       530
# weighted avg       0.91      0.91      0.91       530
